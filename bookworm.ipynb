# %% [markdown]
# # Bookworm
#
#
# ## Overview
#
# In this project, you will build a simple question-answering agent that is able to learn from any text data you provide, and answer queries posed in natural language. You will use IBM Watson's cloud-based services to process the input text data and find relevant responses.
#
# ## Learning Objectives
#
# By completing this project, you will learn how to:
#
# - Create a cloud-based NLP service instance and configure it.
# - Ingest a set of text documents using the service and analyze the results.
# - Accept questions in natural language and parse them.
# - Find relevant answers from the preprocessed text data.
#
# ## Getting Started
#
# In order to use Watson's cloud-based services, you first need to create an account on the [IBM Bluemix platform](https://console.ng.bluemix.net/).
#
# <div>
#     <div style="display: table-cell; width: 50%;">
#         <img src="images/watson-logo.png" alt="IBM Watson logo" width="200" />
#     </div>
#     <div style="display: table-cell; width: 50%;">
#         <img src="images/bluemix-logo.png" alt="IBM Bluemix logo" width="400" />
#     </div>
# </div>
#
# Then, for each service you want to use, you have to create an instance of that service. You can continue with the tasks below, and create a service instance when indicated.

# %% [markdown]
# ## 1. Create and configure Discovery service
#
# Create an instance of the **Discovery** service. You will use this to process a set of text documents, and _discover_ relevant facts and relationships.
#
# - Go to the [IBM Bluemix Catalog](https://console.ng.bluemix.net/catalog/?taxonomyNavigation=services&category=watson).
# - Select the service you want, **Discovery**, under the **Watson** category.
# - Enter a Service Name for that instance, e.g. **Disco1** and a Credential Name, e.g. **Disco1-Creds** (these are just for you to be able to refer to later, they do not affect the functioning of the service).
# - You should be able to see your newly-created service in your [Services Dashboard](https://console.ng.bluemix.net/dashboard/services).
# - Open the service instance, click on the **Service credentials** tab, and then **View credentials** under Actions. This is where you will find the username and password to use when connecting to the service.
#
# <img src="images/discovery-creds.png" alt="Discovery Service - Credentials tab" width="800" />
#
# Save the credentials for the discovery service in a JSON file in the current directory named `service-credentials.json` with the following format:
#
# ```json
# {
#     "discovery": {
#         "username": "<your Discovery username here>",
#         "password": "<your Discovery password here>"
#     },
#     "conversation": {
#         "username": "",
#         "password": ""
#     }
# }
#
# ```
#
# You will be filling out the Conversation service credentials later, when you create an instance for it. Note that you should keep these credentials secret. Please do not turn them in with your submission!
#
# ### Connect to the service instance
#
# Let's connect to the service instance you just created using IBM Watson's [Python SDK](https://github.com/watson-developer-cloud/python-sdk). You will first need to install the SDK:
# ```bash
# pip install watson-developer-cloud
# ```
#
# Now execute each code cell below using **`Shift+Enter`**, and complete any steps indicated by a **`TODO`** comment. For more information on the Discovery service, please read the [Documentation](https://www.ibm.com/watson/developercloud/doc/discovery/index.html) and look at the [API Reference](https://www.ibm.com/watson/developercloud/discovery/api/v1/?python) as needed.

# %%
# Usual Python imports
import sys
import os
import glob
import json

# BeautifulSoup, for parsing HTML
from bs4 import BeautifulSoup

# Matplotlib, for plotting
import matplotlib.pyplot as plt
# %matplotlib inline

# Watson Python SDK
import watson_developer_cloud

# Utility functions
import helper

# %%
# Connect to the Discovery service instance
# TODO: Ensure that your username and password from the Service Credentials tab are in service-credentials.json
# Note that these credentials are different from your IBM Bluemix login, and are specific to the service instance
discovery_creds = helper.fetch_credentials('discovery')
discovery = watson_developer_cloud.DiscoveryV1(
    version='2016-11-07',
#     version='2017-09-01',
    username=discovery_creds['username'],
    password=discovery_creds['password'])

# %% [markdown]
# ### Create an environment
#
# The Discovery service organizes everything needed for a particular application in an _environment_. Let's create one called "Bookworm" for this project.
#
# > _**Note**: It is okay to run this block multiple times - it will not create duplicate environments with the same name._

# %%
# Prepare an environment to work in
env, env_id = helper.fetch_object(
    discovery, "environment", "Bookworm",
    create=True, create_args=dict(
        description="A space to read and understand stories",  # feel free to edit
        size=0  # use 0 for free plan (see API reference for more on sizing)
    ))
print(json.dumps(env, indent=2))
# Out:
# Found environment: Bookworm (b7207c9b-9376-4085-aec3-bcb27834934e)
# {
#   "environment_id": "b7207c9b-9376-4085-aec3-bcb27834934e",
#   "name": "Bookworm",
#   "description": "A space to read and understand stories",
#   "created": "2018-08-19T11:30:19.343Z",
#   "updated": "2018-08-19T11:30:19.343Z",
#   "status": "active",
#   "read_only": false,
#   "size": -1,
#   "index_capacity": {
#     "documents": {
#       "available": 42,
#       "maximum_allowed": 1000
#     },
#     "disk_usage": {
#       "used_bytes": 1169843,
#       "total_bytes": 200000000,
#       "used": "1.1698 MB",
#       "total": "200 MB",
#       "percent_used": 0.58
#     },
#     "memory_usage": {
#       "used_bytes": -1,
#       "total_bytes": -1,
#       "used": "N/A",
#       "total": "N/A",
#       "percent_used": -1.0
#     }
#   }
# }

# %% [markdown]
# ### Verify configuration options
#
# A _configuration_ defines what natural language processing routines are applied to any documents that are submitted to the service. Each environment gets a default configuration when it is created.
#
# You can fetch the default configuration and view the different options using the following piece of code.

# %%
# View default configuration
# cfg_id = discovery.get_default_configuration_id(environment_id=env_id)
# cfg_id = cfg_ids['configurations'][0]['configuration_id']
cfg_ids = discovery.list_configurations(environment_id=env_id)
cfg_name = 'bookwormConfig'
for cfg in cfg_ids['configurations']:
    if cfg['name'] == cfg_name:
        cfg_id = cfg['configuration_id']
cfg = discovery.get_configuration(environment_id=env_id, configuration_id=cfg_id)
print(json.dumps(cfg, indent=2))
# Out:
# {
#   "configuration_id": "ccb9dcb5-4cf3-435b-bc4d-b562694f74a9",
#   "name": "bookwormConfig",
#   "description": null,
#   "created": "2018-08-19T20:12:56.195Z",
#   "updated": "2018-08-19T20:13:38.331Z",
#   "conversions": {
#     "pdf": {
#       "heading": {
#         "fonts": [
#           {
#             "level": 1,
#             "min_size": 24,
#             "max_size": 80
#           },
#           {
#             "level": 2,
#             "min_size": 18,
#             "max_size": 24,
#             "bold": false,
#             "italic": false
#           },
#           {
#             "level": 2,
#             "min_size": 18,
#             "max_size": 24,
#             "bold": true
#           },
#           {
#             "level": 3,
#             "min_size": 13,
#             "max_size": 18,
#             "bold": false,
#             "italic": false
#           },
#           {
#             "level": 3,
#             "min_size": 13,
#             "max_size": 18,
#             "bold": true
#           },
#           {
#             "level": 4,
#             "min_size": 11,
#             "max_size": 13,
#             "bold": false,
#             "italic": false
#           }
#         ]
#       }
#     },
#     "word": {
#       "heading": {
#         "fonts": [
#           {
#             "level": 1,
#             "min_size": 24,
#             "bold": false,
#             "italic": false
#           },
#           {
#             "level": 2,
#             "min_size": 18,
#             "max_size": 23,
#             "bold": true,
#             "italic": false
#           },
#           {
#             "level": 3,
#             "min_size": 14,
#             "max_size": 17,
#             "bold": false,
#             "italic": false
#           },
#           {
#             "level": 4,
#             "min_size": 13,
#             "max_size": 13,
#             "bold": true,
#             "italic": false
#           }
#         ],
#         "styles": [
#           {
#             "level": 1,
#             "names": [
#               "pullout heading",
#               "pulloutheading",
#               "header"
#             ]
#           },
#           {
#             "level": 2,
#             "names": [
#               "subtitle"
#             ]
#           }
#         ]
#       }
#     },
#     "html": {
#       "exclude_tags_completely": [
#         "script",
#         "sup"
#       ],
#       "exclude_tags_keep_content": [
#         "font",
#         "em",
#         "span"
#       ],
#       "exclude_content": {
#         "xpaths": []
#       },
#       "keep_content": {
#         "xpaths": []
#       },
#       "exclude_tag_attributes": [
#         "EVENT_ACTIONS"
#       ]
#     },
#     "json_normalizations": [],
#     "segment": {}
#   },
#   "enrichments": [
#     {
#       "enrichment": "natural_language_understanding",
#       "source_field": "text",
#       "destination_field": "enriched_text",
#       "options": {
#         "features": {
#           "keywords": {},
#           "entities": {
#             "sentiment": true,
#             "emotion": false,
#             "limit": 50
#           },
#           "sentiment": {
#             "document": true
#           },
#           "categories": {},
#           "relations": {},
#           "concepts": {
#             "limit": 8
#           }
#         }
#       }
#     }
#   ],
#   "normalizations": []
# }

# %% [markdown]
# There are 3 main configuration blocks that affect how input documents are processed:
#
# 1. **`conversions`**: How to convert documents in various formats (Word, PDF, HTML) and extract elements that indicate some structure (e.g. headings).
# 2. **`enrichments`**: What NLP output results are we interested in (keywords, entities, sentiment, etc.).
# 3. **`normalizations`**: Post-processing steps to be applied to the output. This can be left empty in most cases, unless you need the output to be normalized into a very specific format.
#
# _**Note**: The default configuration for an environment cannot be modified. If you need to change any of the options, you will need to create a new one, and then edit it. The easiest way to do this is using the service dashboard, which is described later._

# %% [markdown]
# ### Test your configuration
#
# It is a good idea to test your configuration on a small sample text before you apply it to a larger document collection.
#
# _**Note**: We have supplied a sample document (`data/sample.html`) containing the opening crawl text for Star Wars: Episode IV, but you are free to use a text of your choosing._
#
# **Q**: (optional) If you use your own sample text, provide a brief title and description below.
#
# **A**:

# %%
# Test configuration on some sample text
data_dir = "data"
filename = os.path.join(data_dir, "sample.html")

with open(filename, "r") as f:
#     res = discovery.test_document(environment_id=env_id, configuration_id=cfg_id, fileinfo=f)
    res = discovery.test_configuration_in_environment(environment_id=env_id, configuration_id=cfg_id, file=f)
print(json.dumps(res, indent=2))
# Out:
# {
#   "status": "completed",
#   "original_media_type": "text/html",
#   "snapshots": [
#     {
#       "step": "html_input",
#       "snapshot": {
#         "html": "<html>\n<head>\n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n</head>\n<body>\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body>"
#       }
#     },
#     {
#       "step": "html_output",
#       "snapshot": {
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n</head>\n<body>\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>"
#       }
#     },
#     {
#       "step": "json_output",
#       "snapshot": {
#         "extracted_metadata": {
#           "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#         },
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>",
#         "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy..."
#       }
#     },
#     {
#       "step": "json_normalizations_output",
#       "snapshot": {
#         "extracted_metadata": {
#           "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#         },
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>",
#         "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy..."
#       }
#     },
#     {
#       "step": "enrichments_output",
#       "snapshot": {
#         "extracted_metadata": {
#           "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#         },
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>",
#         "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#         "enriched_text": {
#           "sentiment": {
#             "document": {
#               "score": -0.575489,
#               "label": "negative"
#             }
#           },
#           "relations": [
#             {
#               "type": "memberOf",
#               "sentence": "Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#               "score": 0.41176,
#               "arguments": [
#                 {
#                   "text": "agents",
#                   "location": [
#                     460,
#                     466
#                   ],
#                   "entities": [
#                     {
#                       "type": "Person",
#                       "text": "agents"
#                     }
#                   ]
#                 },
#                 {
#                   "text": "Empire",
#                   "location": [
#                     442,
#                     448
#                   ],
#                   "entities": [
#                     {
#                       "type": "Organization",
#                       "text": "Empire"
#                     }
#                   ]
#                 }
#               ]
#             },
#             {
#               "type": "agentOf",
#               "sentence": "Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#               "score": 0.468054,
#               "arguments": [
#                 {
#                   "text": "her",
#                   "location": [
#                     500,
#                     503
#                   ],
#                   "entities": [
#                     {
#                       "type": "Person",
#                       "text": "Princess Leia"
#                     }
#                   ]
#                 },
#                 {
#                   "text": "stolen",
#                   "location": [
#                     531,
#                     537
#                   ],
#                   "entities": [
#                     {
#                       "type": "Crime",
#                       "text": "stolen"
#                     }
#                   ]
#                 }
#               ]
#             },
#             {
#               "type": "affectedBy",
#               "sentence": "Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#               "score": 0.316489,
#               "arguments": [
#                 {
#                   "text": "people",
#                   "location": [
#                     562,
#                     568
#                   ],
#                   "entities": [
#                     {
#                       "type": "Person",
#                       "text": "people"
#                     }
#                   ]
#                 },
#                 {
#                   "text": "stolen",
#                   "location": [
#                     531,
#                     537
#                   ],
#                   "entities": [
#                     {
#                       "type": "Crime",
#                       "text": "stolen"
#                     }
#                   ]
#                 }
#               ]
#             }
#           ],
#           "keywords": [
#             {
#               "text": "Opening Crawl",
#               "relevance": 0.920159
#             },
#             {
#               "text": "New Hope",
#               "relevance": 0.785031
#             },
#             {
#               "text": "Princess Leia races",
#               "relevance": 0.775799
#             },
#             {
#               "text": "Star Wars",
#               "relevance": 0.771384
#             },
#             {
#               "text": "evil Galactic Empire",
#               "relevance": 0.767527
#             },
#             {
#               "text": "armored space station",
#               "relevance": 0.747615
#             },
#             {
#               "text": "Rebel spaceships",
#               "relevance": 0.669776
#             },
#             {
#               "text": "Rebel spies",
#               "relevance": 0.656828
#             },
#             {
#               "text": "sinister agents",
#               "relevance": 0.609404
#             },
#             {
#               "text": "civil war",
#               "relevance": 0.600682
#             },
#             {
#               "text": "hidden base",
#               "relevance": 0.597836
#             },
#             {
#               "text": "ultimate weapon",
#               "relevance": 0.594694
#             },
#             {
#               "text": "secret plans",
#               "relevance": 0.582765
#             },
#             {
#               "text": "entire planet",
#               "relevance": 0.582596
#             },
#             {
#               "text": "DEATH STAR",
#               "relevance": 0.574413
#             },
#             {
#               "text": "custodian",
#               "relevance": 0.465394
#             },
#             {
#               "text": "Episode",
#               "relevance": 0.462247
#             },
#             {
#               "text": "starship",
#               "relevance": 0.443969
#             },
#             {
#               "text": "victory",
#               "relevance": 0.441799
#             },
#             {
#               "text": "galaxy",
#               "relevance": 0.437824
#             },
#             {
#               "text": "period",
#               "relevance": 0.432092
#             },
#             {
#               "text": "battle",
#               "relevance": 0.429238
#             },
#             {
#               "text": "home",
#               "relevance": 0.428916
#             },
#             {
#               "text": "people",
#               "relevance": 0.428498
#             }
#           ],
#           "entities": [],
#           "concepts": [
#             {
#               "text": "Star Wars Episode IV: A New Hope",
#               "relevance": 0.98887,
#               "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope"
#             },
#             {
#               "text": "Star Wars",
#               "relevance": 0.985705,
#               "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars"
#             },
#             {
#               "text": "Rebel Alliance",
#               "relevance": 0.90639,
#               "dbpedia_resource": "http://dbpedia.org/resource/Rebel_Alliance"
#             },
#             {
#               "text": "Luke Skywalker",
#               "relevance": 0.805771,
#               "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#             },
#             {
#               "text": "Star Wars Episode V: The Empire Strikes Back",
#               "relevance": 0.801062,
#               "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back"
#             },
#             {
#               "text": "Darth Vader",
#               "relevance": 0.777337,
#               "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#             },
#             {
#               "text": "Star Wars Episode VI: Return of the Jedi",
#               "relevance": 0.77159,
#               "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi"
#             },
#             {
#               "text": "Grand Moff Tarkin",
#               "relevance": 0.748553,
#               "dbpedia_resource": "http://dbpedia.org/resource/Grand_Moff_Tarkin"
#             }
#           ],
#           "categories": [
#             {
#               "score": 0.584247,
#               "label": "/art and entertainment/movies and tv/movies"
#             },
#             {
#               "score": 0.517031,
#               "label": "/society/unrest and war"
#             },
#             {
#               "score": 0.215561,
#               "label": "/law, govt and politics/armed forces/army"
#             }
#           ]
#         }
#       }
#     },
#     {
#       "step": "normalizations_output",
#       "snapshot": {
#         "extracted_metadata": {
#           "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#         },
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>",
#         "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#         "enriched_text": {
#           "sentiment": {
#             "document": {
#               "score": -0.575489,
#               "label": "negative"
#             }
#           },
#           "relations": [
#             {
#               "type": "memberOf",
#               "sentence": "Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#               "score": 0.41176,
#               "arguments": [
#                 {
#                   "text": "agents",
#                   "location": [
#                     460,
#                     466
#                   ],
#                   "entities": [
#                     {
#                       "type": "Person",
#                       "text": "agents"
#                     }
#                   ]
#                 },
#                 {
#                   "text": "Empire",
#                   "location": [
#                     442,
#                     448
#                   ],
#                   "entities": [
#                     {
#                       "type": "Organization",
#                       "text": "Empire"
#                     }
#                   ]
#                 }
#               ]
#             },
#             {
#               "type": "agentOf",
#               "sentence": "Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#               "score": 0.468054,
#               "arguments": [
#                 {
#                   "text": "her",
#                   "location": [
#                     500,
#                     503
#                   ],
#                   "entities": [
#                     {
#                       "type": "Person",
#                       "text": "Princess Leia"
#                     }
#                   ]
#                 },
#                 {
#                   "text": "stolen",
#                   "location": [
#                     531,
#                     537
#                   ],
#                   "entities": [
#                     {
#                       "type": "Crime",
#                       "text": "stolen"
#                     }
#                   ]
#                 }
#               ]
#             },
#             {
#               "type": "affectedBy",
#               "sentence": "Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#               "score": 0.316489,
#               "arguments": [
#                 {
#                   "text": "people",
#                   "location": [
#                     562,
#                     568
#                   ],
#                   "entities": [
#                     {
#                       "type": "Person",
#                       "text": "people"
#                     }
#                   ]
#                 },
#                 {
#                   "text": "stolen",
#                   "location": [
#                     531,
#                     537
#                   ],
#                   "entities": [
#                     {
#                       "type": "Crime",
#                       "text": "stolen"
#                     }
#                   ]
#                 }
#               ]
#             }
#           ],
#           "keywords": [
#             {
#               "text": "Opening Crawl",
#               "relevance": 0.920159
#             },
#             {
#               "text": "New Hope",
#               "relevance": 0.785031
#             },
#             {
#               "text": "Princess Leia races",
#               "relevance": 0.775799
#             },
#             {
#               "text": "Star Wars",
#               "relevance": 0.771384
#             },
#             {
#               "text": "evil Galactic Empire",
#               "relevance": 0.767527
#             },
#             {
#               "text": "armored space station",
#               "relevance": 0.747615
#             },
#             {
#               "text": "Rebel spaceships",
#               "relevance": 0.669776
#             },
#             {
#               "text": "Rebel spies",
#               "relevance": 0.656828
#             },
#             {
#               "text": "sinister agents",
#               "relevance": 0.609404
#             },
#             {
#               "text": "civil war",
#               "relevance": 0.600682
#             },
#             {
#               "text": "hidden base",
#               "relevance": 0.597836
#             },
#             {
#               "text": "ultimate weapon",
#               "relevance": 0.594694
#             },
#             {
#               "text": "secret plans",
#               "relevance": 0.582765
#             },
#             {
#               "text": "entire planet",
#               "relevance": 0.582596
#             },
#             {
#               "text": "DEATH STAR",
#               "relevance": 0.574413
#             },
#             {
#               "text": "custodian",
#               "relevance": 0.465394
#             },
#             {
#               "text": "Episode",
#               "relevance": 0.462247
#             },
#             {
#               "text": "starship",
#               "relevance": 0.443969
#             },
#             {
#               "text": "victory",
#               "relevance": 0.441799
#             },
#             {
#               "text": "galaxy",
#               "relevance": 0.437824
#             },
#             {
#               "text": "period",
#               "relevance": 0.432092
#             },
#             {
#               "text": "battle",
#               "relevance": 0.429238
#             },
#             {
#               "text": "home",
#               "relevance": 0.428916
#             },
#             {
#               "text": "people",
#               "relevance": 0.428498
#             }
#           ],
#           "entities": [],
#           "concepts": [
#             {
#               "text": "Star Wars Episode IV: A New Hope",
#               "relevance": 0.98887,
#               "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope"
#             },
#             {
#               "text": "Star Wars",
#               "relevance": 0.985705,
#               "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars"
#             },
#             {
#               "text": "Rebel Alliance",
#               "relevance": 0.90639,
#               "dbpedia_resource": "http://dbpedia.org/resource/Rebel_Alliance"
#             },
#             {
#               "text": "Luke Skywalker",
#               "relevance": 0.805771,
#               "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#             },
#             {
#               "text": "Star Wars Episode V: The Empire Strikes Back",
#               "relevance": 0.801062,
#               "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back"
#             },
#             {
#               "text": "Darth Vader",
#               "relevance": 0.777337,
#               "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#             },
#             {
#               "text": "Star Wars Episode VI: Return of the Jedi",
#               "relevance": 0.77159,
#               "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi"
#             },
#             {
#               "text": "Grand Moff Tarkin",
#               "relevance": 0.748553,
#               "dbpedia_resource": "http://dbpedia.org/resource/Grand_Moff_Tarkin"
#             }
#           ],
#           "categories": [
#             {
#               "score": 0.584247,
#               "label": "/art and entertainment/movies and tv/movies"
#             },
#             {
#               "score": 0.517031,
#               "label": "/society/unrest and war"
#             },
#             {
#               "score": 0.215561,
#               "label": "/law, govt and politics/armed forces/army"
#             }
#           ]
#         }
#       }
#     },
#     {
#       "step": "filtering_output",
#       "snapshot": {
#         "extracted_metadata": {
#           "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#         },
#         "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>",
#         "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#         "enriched_text": {
#           "sentiment": {
#             "document": {
#               "score": -0.575489,
#               "label": "negative"
#             }
#           },
#           "relations": [
#             {
#               "type": "memberOf",
#               "sentence": "Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#               "score": 0.41176,
#               "arguments": [
#                 {
#                   "text": "agents",
#                   "location": [
#                     460,
#                     466
#                   ],
#                   "entities": [
#                     {
#                       "type": "Person",
#                       "text": "agents"
#                     }
#                   ]
#                 },
#                 {
#                   "text": "Empire",
#                   "location": [
#                     442,
#                     448
#                   ],
#                   "entities": [
#                     {
#                       "type": "Organization",
#                       "text": "Empire"
#                     }
#                   ]
#                 }
#               ]
#             },
#             {
#               "type": "agentOf",
#               "sentence": "Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#               "score": 0.468054,
#               "arguments": [
#                 {
#                   "text": "her",
#                   "location": [
#                     500,
#                     503
#                   ],
#                   "entities": [
#                     {
#                       "type": "Person",
#                       "text": "Princess Leia"
#                     }
#                   ]
#                 },
#                 {
#                   "text": "stolen",
#                   "location": [
#                     531,
#                     537
#                   ],
#                   "entities": [
#                     {
#                       "type": "Crime",
#                       "text": "stolen"
#                     }
#                   ]
#                 }
#               ]
#             },
#             {
#               "type": "affectedBy",
#               "sentence": "Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#               "score": 0.316489,
#               "arguments": [
#                 {
#                   "text": "people",
#                   "location": [
#                     562,
#                     568
#                   ],
#                   "entities": [
#                     {
#                       "type": "Person",
#                       "text": "people"
#                     }
#                   ]
#                 },
#                 {
#                   "text": "stolen",
#                   "location": [
#                     531,
#                     537
#                   ],
#                   "entities": [
#                     {
#                       "type": "Crime",
#                       "text": "stolen"
#                     }
#                   ]
#                 }
#               ]
#             }
#           ],
#           "keywords": [
#             {
#               "text": "Opening Crawl",
#               "relevance": 0.920159
#             },
#             {
#               "text": "New Hope",
#               "relevance": 0.785031
#             },
#             {
#               "text": "Princess Leia races",
#               "relevance": 0.775799
#             },
#             {
#               "text": "Star Wars",
#               "relevance": 0.771384
#             },
#             {
#               "text": "evil Galactic Empire",
#               "relevance": 0.767527
#             },
#             {
#               "text": "armored space station",
#               "relevance": 0.747615
#             },
#             {
#               "text": "Rebel spaceships",
#               "relevance": 0.669776
#             },
#             {
#               "text": "Rebel spies",
#               "relevance": 0.656828
#             },
#             {
#               "text": "sinister agents",
#               "relevance": 0.609404
#             },
#             {
#               "text": "civil war",
#               "relevance": 0.600682
#             },
#             {
#               "text": "hidden base",
#               "relevance": 0.597836
#             },
#             {
#               "text": "ultimate weapon",
#               "relevance": 0.594694
#             },
#             {
#               "text": "secret plans",
#               "relevance": 0.582765
#             },
#             {
#               "text": "entire planet",
#               "relevance": 0.582596
#             },
#             {
#               "text": "DEATH STAR",
#               "relevance": 0.574413
#             },
#             {
#               "text": "custodian",
#               "relevance": 0.465394
#             },
#             {
#               "text": "Episode",
#               "relevance": 0.462247
#             },
#             {
#               "text": "starship",
#               "relevance": 0.443969
#             },
#             {
#               "text": "victory",
#               "relevance": 0.441799
#             },
#             {
#               "text": "galaxy",
#               "relevance": 0.437824
#             },
#             {
#               "text": "period",
#               "relevance": 0.432092
#             },
#             {
#               "text": "battle",
#               "relevance": 0.429238
#             },
#             {
#               "text": "home",
#               "relevance": 0.428916
#             },
#             {
#               "text": "people",
#               "relevance": 0.428498
#             }
#           ],
#           "entities": [],
#           "concepts": [
#             {
#               "text": "Star Wars Episode IV: A New Hope",
#               "relevance": 0.98887,
#               "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope"
#             },
#             {
#               "text": "Star Wars",
#               "relevance": 0.985705,
#               "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars"
#             },
#             {
#               "text": "Rebel Alliance",
#               "relevance": 0.90639,
#               "dbpedia_resource": "http://dbpedia.org/resource/Rebel_Alliance"
#             },
#             {
#               "text": "Luke Skywalker",
#               "relevance": 0.805771,
#               "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#             },
#             {
#               "text": "Star Wars Episode V: The Empire Strikes Back",
#               "relevance": 0.801062,
#               "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back"
#             },
#             {
#               "text": "Darth Vader",
#               "relevance": 0.777337,
#               "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#             },
#             {
#               "text": "Star Wars Episode VI: Return of the Jedi",
#               "relevance": 0.77159,
#               "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi"
#             },
#             {
#               "text": "Grand Moff Tarkin",
#               "relevance": 0.748553,
#               "dbpedia_resource": "http://dbpedia.org/resource/Grand_Moff_Tarkin"
#             }
#           ],
#           "categories": [
#             {
#               "score": 0.584247,
#               "label": "/art and entertainment/movies and tv/movies"
#             },
#             {
#               "score": 0.517031,
#               "label": "/society/unrest and war"
#             },
#             {
#               "score": 0.215561,
#               "label": "/law, govt and politics/armed forces/army"
#             }
#           ]
#         }
#       }
#     }
#   ],
#   "notices": []
# }

# %% [markdown]
# ### Analyze test output
#
# The results returned by the service contain a _snapshot_ of the information extracted at each step of processing - document conversions, enrichments and normalizations. We are interested in the output of applying enrichments (`"enrichments_output"`) or after normalizing them (`"normalizations_output"`). These should be identical if no post-processing/normalizations were specified in the configuration.

# %%
# Take a closer look at the results from the "enrichments_output" or "normalizations_output" step
output = next((s["snapshot"] for s in res["snapshots"] if s["step"] == "enrichments_output"), None)
print(json.dumps(output, indent=2))
# Out:
# {
#   "extracted_metadata": {
#     "title": "Star Wars: Episode IV - A New Hope (Opening Crawl)"
#   },
#   "html": "<?xml version='1.0' encoding='UTF-8' standalone='yes'?><html>\n<head>\n    <meta content=\"text/html; charset=UTF-8\" http-equiv=\"Content-Type\"/>\n    \n    <title>Star Wars: Episode IV - A New Hope (Opening Crawl)</title>\n\n\n</head>\n<body>\n\n\n    <article>\n        <h1>Star Wars: Episode IV - A New Hope (Opening Crawl)</h1>\n        <p>\n            It is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n        </p><p>\n            During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n        </p><p>\n            Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...\n        </p>\n    </article>\n</body></html>",
#   "text": "Star Wars: Episode IV - A New Hope (Opening Crawl)\n\nStar Wars: Episode IV - A New Hope (Opening Crawl)\n\nIt is a period of civil war. Rebel spaceships, striking from a hidden base, have won their first victory against the evil Galactic Empire.\n\nDuring the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.\n\nPursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#   "enriched_text": {
#     "sentiment": {
#       "document": {
#         "score": -0.575489,
#         "label": "negative"
#       }
#     },
#     "relations": [
#       {
#         "type": "memberOf",
#         "sentence": "Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#         "score": 0.41176,
#         "arguments": [
#           {
#             "text": "agents",
#             "location": [
#               460,
#               466
#             ],
#             "entities": [
#               {
#                 "type": "Person",
#                 "text": "agents"
#               }
#             ]
#           },
#           {
#             "text": "Empire",
#             "location": [
#               442,
#               448
#             ],
#             "entities": [
#               {
#                 "type": "Organization",
#                 "text": "Empire"
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "type": "agentOf",
#         "sentence": "Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#         "score": 0.468054,
#         "arguments": [
#           {
#             "text": "her",
#             "location": [
#               500,
#               503
#             ],
#             "entities": [
#               {
#                 "type": "Person",
#                 "text": "Princess Leia"
#               }
#             ]
#           },
#           {
#             "text": "stolen",
#             "location": [
#               531,
#               537
#             ],
#             "entities": [
#               {
#                 "type": "Crime",
#                 "text": "stolen"
#               }
#             ]
#           }
#         ]
#       },
#       {
#         "type": "affectedBy",
#         "sentence": "Pursued by the Empire's sinister agents, Princess Leia races home aboard her starship, custodian of the stolen plans that can save her people and restore freedom to the galaxy...",
#         "score": 0.316489,
#         "arguments": [
#           {
#             "text": "people",
#             "location": [
#               562,
#               568
#             ],
#             "entities": [
#               {
#                 "type": "Person",
#                 "text": "people"
#               }
#             ]
#           },
#           {
#             "text": "stolen",
#             "location": [
#               531,
#               537
#             ],
#             "entities": [
#               {
#                 "type": "Crime",
#                 "text": "stolen"
#               }
#             ]
#           }
#         ]
#       }
#     ],
#     "keywords": [
#       {
#         "text": "Opening Crawl",
#         "relevance": 0.920159
#       },
#       {
#         "text": "New Hope",
#         "relevance": 0.785031
#       },
#       {
#         "text": "Princess Leia races",
#         "relevance": 0.775799
#       },
#       {
#         "text": "Star Wars",
#         "relevance": 0.771384
#       },
#       {
#         "text": "evil Galactic Empire",
#         "relevance": 0.767527
#       },
#       {
#         "text": "armored space station",
#         "relevance": 0.747615
#       },
#       {
#         "text": "Rebel spaceships",
#         "relevance": 0.669776
#       },
#       {
#         "text": "Rebel spies",
#         "relevance": 0.656828
#       },
#       {
#         "text": "sinister agents",
#         "relevance": 0.609404
#       },
#       {
#         "text": "civil war",
#         "relevance": 0.600682
#       },
#       {
#         "text": "hidden base",
#         "relevance": 0.597836
#       },
#       {
#         "text": "ultimate weapon",
#         "relevance": 0.594694
#       },
#       {
#         "text": "secret plans",
#         "relevance": 0.582765
#       },
#       {
#         "text": "entire planet",
#         "relevance": 0.582596
#       },
#       {
#         "text": "DEATH STAR",
#         "relevance": 0.574413
#       },
#       {
#         "text": "custodian",
#         "relevance": 0.465394
#       },
#       {
#         "text": "Episode",
#         "relevance": 0.462247
#       },
#       {
#         "text": "starship",
#         "relevance": 0.443969
#       },
#       {
#         "text": "victory",
#         "relevance": 0.441799
#       },
#       {
#         "text": "galaxy",
#         "relevance": 0.437824
#       },
#       {
#         "text": "period",
#         "relevance": 0.432092
#       },
#       {
#         "text": "battle",
#         "relevance": 0.429238
#       },
#       {
#         "text": "home",
#         "relevance": 0.428916
#       },
#       {
#         "text": "people",
#         "relevance": 0.428498
#       }
#     ],
#     "entities": [],
#     "concepts": [
#       {
#         "text": "Star Wars Episode IV: A New Hope",
#         "relevance": 0.98887,
#         "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope"
#       },
#       {
#         "text": "Star Wars",
#         "relevance": 0.985705,
#         "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars"
#       },
#       {
#         "text": "Rebel Alliance",
#         "relevance": 0.90639,
#         "dbpedia_resource": "http://dbpedia.org/resource/Rebel_Alliance"
#       },
#       {
#         "text": "Luke Skywalker",
#         "relevance": 0.805771,
#         "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#       },
#       {
#         "text": "Star Wars Episode V: The Empire Strikes Back",
#         "relevance": 0.801062,
#         "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back"
#       },
#       {
#         "text": "Darth Vader",
#         "relevance": 0.777337,
#         "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#       },
#       {
#         "text": "Star Wars Episode VI: Return of the Jedi",
#         "relevance": 0.77159,
#         "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi"
#       },
#       {
#         "text": "Grand Moff Tarkin",
#         "relevance": 0.748553,
#         "dbpedia_resource": "http://dbpedia.org/resource/Grand_Moff_Tarkin"
#       }
#     ],
#     "categories": [
#       {
#         "score": 0.584247,
#         "label": "/art and entertainment/movies and tv/movies"
#       },
#       {
#         "score": 0.517031,
#         "label": "/society/unrest and war"
#       },
#       {
#         "score": 0.215561,
#         "label": "/law, govt and politics/armed forces/army"
#       }
#     ]
#   }
# }

# %% [markdown]
# Answer the following questions based on the output above. Note that it contains the input HTML, extracted text and metadata as well as the actual enrichment results (`"enriched_text"` block).
#
# #### Sentiment
#
# **Q**: What is the overall sentiment detected in this text? Mention the `type` (positive/negative) and `score`.<br />
# (_Hint: Look for the `"docSentiment"` key in the output._)
#
# **A**: Negative, -0.575489
#
#
# #### Concepts
#
# **Q**: List 3 concepts that have been identified with a relevance > 0.5. Note that not all concepts here may be present directly in the text, some may have been inferred by Watson.<br />
# (_Hint: Look for `"concepts"`._)
#
# **A**: Star Wars Episode IV: A New Hope (relevance: 0.98887) <br/>
#        Star Wars(relevance: 0.985705)<br/>
#        Rebel Alliance(relevance: 0.90639)<br/>
#
#
# #### Relations
#
# Each relation is essentially a deeper analysis of a sentence (or part of a sentence). Here is a sample relation:
# ```json
# {
#   "sentence": " During the battle, Rebel spies managed to steal secret plans to the Empire's ultimate weapon, the DEATH STAR, an armored space station with enough power to destroy an entire planet.",
#   "subject": {
#     "text": "Rebel spies",
#     "keywords": [
#       {
#         "text": "Rebel spies"
#       }
#     ]
#   },
#   "action": {
#     "text": "managed to steal",
#     "lemmatized": "manage to steal",
#     "verb": {
#       "text": "steal",
#       "tense": "future"
#     }
#   },
#   "object": {
#     "text": "secret plans",
#     "keywords": [
#       {
#         "text": "secret plans"
#       }
#     ]
#   }
#  }
# ```
#
# In this case, Watson seems to have done a pretty good job of extracting some meaning from the sentence.
#
# **Q**: Find a relation where the extracted meaning is not as accurate, or not what you would've expected. List the `sentence`, `subject`, `action` and `object` parts as identified, and what you would've marked instead.<br />
# (_Hint: Look for `"relations"`._)
#
# **A**:
#
# #### Keywords
#
# You may have noticed that Watson identifies some `"keywords"` in the relations, e.g. `"Rebel spies"` and `"secret plans"` in the Star Wars example above. The output also contains a list of all keywords at the top level, for your convenience, along with their relevance to the document and sentiment conveyed. Let's visualize these keywords as a word cloud!
#
# Note: We'll be using this handy [worldcoud library](https://github.com/amueller/word_cloud) to generate the visualization. So you will need to install it first:
# ```bash
# pip install wordcloud
# ```

# %%
# Visualize keywords by relevance as a wordcloud
from wordcloud import WordCloud

wc_data = { w["text"]: w["relevance"] for w in output["enriched_text"]["keywords"] }
wc = WordCloud(width=400, height=300, scale=2, background_color="white", colormap="Accent")
wc.generate_from_frequencies(wc_data)  # use precomputed relevance instead of frequencies

plt.figure(figsize=(4, 3), dpi=200)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 799.5, 599.5, -0.5)

# %% [markdown]
# Feel free to play with this visualization and improve it. What about using a different metric instead of relevance, e.g. direct word frequencies that the wordcloud library computes by default?
#
# #### Other results
#
# Watson's output also includes processed results from other enrichments that were applied to the text, including entities and taxonomy (what topic or category does this text relate to).
#
# ```json
# "taxonomy": [
#   {
#     "label": "/art and entertainment/movies and tv/movies",
#     "score": 0.584247,
#     "confident": false
#   },
#   {
#     "label": "/society/unrest and war",
#     "score": 0.517031,
#     "confident": false
#   },
#   {
#     "confident": false,
#     "label": "/law, govt and politics/armed forces/army",
#     "score": 0.215561
#   }
# ],
# ```
#
# Get a good sense of all the different pieces of information available in the results. Start thinking about which ones will be useful for looking up answers to questions, and how you might use them.

# %% [markdown]
# ## 2. Ingest documents
#
# ### Create a collection
#
# A _collection_ is used to organize documents of the same kind. For instance, you may want to create a collection of book reviews, or a collection of Wikipedia articles, but it may not make much sense to mix the two groups. This allows Watson to make meaningful inferences over the set of documents, find commonalities and identify important concepts.
#
# Let's create one called "Story Chunks".

# %%
# Prepare a collection of documents to use
col, col_id = helper.fetch_object(discovery, "collection", "Story Chunks", environment_id=env_id,
    create=True, create_args=dict(
        environment_id=env_id, configuration_id=cfg_id,
        description="Stories and plots split up into chunks suitable for answering"
    ))
print(json.dumps(col, indent=2))
# Out:
# Found collection: Story Chunks (92425181-087f-4566-a36f-c7fb9c0b8e80)
# {
#   "collection_id": "92425181-087f-4566-a36f-c7fb9c0b8e80",
#   "name": "Story Chunks",
#   "configuration_id": "ccb9dcb5-4cf3-435b-bc4d-b562694f74a9",
#   "language": "en",
#   "status": "active",
#   "description": "Stories and plots split up into chunks suitable for answering",
#   "created": "2018-08-19T19:12:36.802Z",
#   "updated": "2018-08-19T20:12:57.185Z",
#   "document_counts": {
#     "available": 42,
#     "processing": 0,
#     "failed": 0
#   },
#   "disk_usage": {
#     "used_bytes": 1169843
#   },
#   "training_status": {
#     "data_updated": "",
#     "total_examples": 0,
#     "sufficient_label_diversity": false,
#     "processing": false,
#     "minimum_examples_added": false,
#     "successfully_trained": "",
#     "available": false,
#     "notices": 0,
#     "minimum_queries_added": false
#   },
#   "crawl_status": {
#     "source_crawl": {
#       "status": "not_configured"
#     }
#   }
# }

# %% [markdown]
# Once you have created a collection, you should be able to view it using the Discovery Service tool. To open, go to the **Manage** tab for your service instance, and click the **Launch tool** button.
#
# <img src="images/discovery-manage.png" alt="Discovery service - Manage tab" width="800" />

# %% [markdown]
# Here you should see the "Story Chunks" collection you just created.
#
# <img src="images/discovery-tooling.png" alt="Discovery service - Tool showing collections" width="800" />
#
# You can open the collection to view more details about it. If you need to modify configuration options, click the **Switch** link and create a new configuration (the default one cannot be changed).

# %% [markdown]
# ### Add documents
#
# Okay, now that we have everything set up, let's add a set of "documents" we want Watson to look up answers from, using the Python SDK. Note that Watson treats each "document" as a unit of text that is returned as the result of a query. But we want to retrieve a paragraph of text for each question. So, let's split each file up into individual paragraphs. We will use the [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) library for this purpose.
#
# _**Note**: You could also add and manage documents in the collection using the Discovery tool, but you would have to split paragraphs up into separate files._
#
# _**Note**: We have provided a set of files (`data/Star-Wars/*.html`) with summary plots for Star Wars movies, but you are free to use a collection of your choice. Open one of the files in a text editor to see how the paragraphs are delimited using `<p>...</p>` tags - this is how the code block below split paragraphs into separate "documents"._

# %%
# Add documents to collection
doc_ids = []  # to store the generated id for each document added
for filename in glob.glob(os.path.join(data_dir, "Star-Wars", "*.html")):
    print("Adding file:", filename)
    with open(filename, "r") as f:
        # Split each individual <p> into its own "document"
        doc = f.read()
        soup = BeautifulSoup(doc, 'html.parser')
        for i, p in enumerate(soup.find_all('p')):
            file_data=json.dumps({"text": p.get_text(strip=True)})
            mime_type="application/json"
            metadata={"title": soup.title.get_text(strip=True)}
            
            ## Build a temp file to make the post to watson of every paragraph
            with open("temp_json.json", "w") as tempFile:
                tempFile.write(file_data)
            with open("temp_json.json", "r") as tempFile:
                    doc_info = discovery.add_document(environment_id=env_id, collection_id=col_id,
                        file=tempFile,
                        filename=metadata["title"],
                        file_content_type="application/json")
                    doc_ids.append(doc_info["document_id"])
            
#             doc_info = discovery.add_document(environment_id=env_id, collection_id=col_id,
#                 file_data=file_data,
#                 mime_type=mime_type,
#                 metadata=metadata)
#             doc_ids.append(doc_info["document_id"])
print("Total", len(doc_ids), "documents added.")
# Out:
# Adding file: data/Star-Wars/Episode-IV_A-New-Hope.html
# Adding file: data/Star-Wars/Episode-VI_Return-of-the-Jedi.html
# Adding file: data/Star-Wars/Rogue-One.html
# Adding file: data/Star-Wars/Episode-II_Attack-of-the-Clones.html
# Adding file: data/Star-Wars/Episode-III_Revenge-of-the-Sith.html
# Adding file: data/Star-Wars/Episode-VII_The-Force-Awakens.html
# Adding file: data/Star-Wars/Episode-V_The-Empire-Strikes-Back.html
# Adding file: data/Star-Wars/Episode-I_The-Phantom-Menace.html
# Total 42 documents added.

# %% [markdown]
# If you look at the collection details, you may notice that the `"document_counts"` field now shows some documents as `available` or `processing`. Once processing is complete, you should see all the documents under the `available` count.

# %%
# View collection details to verify all documents have been processed
col, col_id = helper.fetch_object(discovery, "collection", "Story Chunks", environment_id=env_id)
print(json.dumps(col, indent=2))
# Out:
# Found collection: Story Chunks (92425181-087f-4566-a36f-c7fb9c0b8e80)
# {
#   "collection_id": "92425181-087f-4566-a36f-c7fb9c0b8e80",
#   "name": "Story Chunks",
#   "configuration_id": "ccb9dcb5-4cf3-435b-bc4d-b562694f74a9",
#   "language": "en",
#   "status": "active",
#   "description": "Stories and plots split up into chunks suitable for answering",
#   "created": "2018-08-19T19:12:36.802Z",
#   "updated": "2018-08-19T20:12:57.185Z",
#   "document_counts": {
#     "available": 78,
#     "processing": 6,
#     "failed": 0
#   },
#   "disk_usage": {
#     "used_bytes": 2299244
#   },
#   "training_status": {
#     "data_updated": "",
#     "total_examples": 0,
#     "sufficient_label_diversity": false,
#     "processing": false,
#     "minimum_examples_added": false,
#     "successfully_trained": "",
#     "available": false,
#     "notices": 0,
#     "minimum_queries_added": false
#   },
#   "crawl_status": {
#     "source_crawl": {
#       "status": "not_configured"
#     }
#   }
# }

# %% [markdown]
# So, what did the Discovery service learn? If you list the fields extracted from the set of documents in the collection as part of the enrichment process, you'll see familiar fields like `concepts`, `entities` and `keywords` that were returned in the test analysis.

# %%
# List all fields extracted
discovery.list_collection_fields(environment_id=env_id, collection_id=col_id)
# Out:
# {'fields': [{'field': 'enriched_text.relations.arguments.entities.disambiguation',
#    'type': 'nested'},
#   {'field': 'enriched_text.entities.sentiment.score', 'type': 'double'},
#   {'field': 'enriched_text.sentiment.document.label', 'type': 'string'},
#   {'field': 'enriched_text.concepts.dbpedia_resource', 'type': 'string'},
#   {'field': 'extracted_metadata.file_type', 'type': 'string'},
#   {'field': 'enriched_text.relations.score', 'type': 'double'},
#   {'field': 'enriched_text.relations.arguments.entities.text',
#    'type': 'string'},
#   {'field': 'enriched_text.concepts.text', 'type': 'string'},
#   {'field': 'enriched_text.relations.arguments.entities.disambiguation.subtype',
#    'type': 'string'},
#   {'field': 'enriched_text.keywords.relevance', 'type': 'double'},
#   {'field': 'enriched_text.concepts.relevance', 'type': 'double'},
#   {'field': 'enriched_text.relations.sentence', 'type': 'string'},
#   {'field': 'enriched_text.categories.score', 'type': 'double'},
#   {'field': 'enriched_text.keywords', 'type': 'nested'},
#   {'field': 'enriched_text.relations', 'type': 'nested'},
#   {'field': 'enriched_text.entities.sentiment.label', 'type': 'string'},
#   {'field': 'enriched_text.relations.type', 'type': 'string'},
#   {'field': 'enriched_text.entities.relevance', 'type': 'double'},
#   {'field': 'text', 'type': 'string'},
#   {'field': 'enriched_text.entities.count', 'type': 'double'},
#   {'field': 'enriched_text.entities.sentiment', 'type': 'nested'},
#   {'field': 'enriched_text.sentiment.document', 'type': 'nested'},
#   {'field': 'enriched_text.keywords.text', 'type': 'string'},
#   {'field': 'enriched_text.entities.text', 'type': 'string'},
#   {'field': 'enriched_text.entities', 'type': 'nested'},
#   {'field': 'enriched_text.entities.disambiguation.name', 'type': 'string'},
#   {'field': 'enriched_text.categories.label', 'type': 'string'},
#   {'field': 'id', 'type': 'string'},
#   {'field': 'enriched_text.relations.arguments.location', 'type': 'double'},
#   {'field': 'enriched_text.concepts', 'type': 'nested'},
#   {'field': 'enriched_text.entities.disambiguation', 'type': 'nested'},
#   {'field': 'enriched_text.entities.type', 'type': 'string'},
#   {'field': 'extracted_metadata.sha1', 'type': 'string'},
#   {'field': 'enriched_text.relations.arguments.text', 'type': 'string'},
#   {'field': 'enriched_text.relations.arguments', 'type': 'nested'},
#   {'field': 'enriched_text.relations.arguments.entities.type',
#    'type': 'string'},
#   {'field': 'enriched_text', 'type': 'nested'},
#   {'field': 'enriched_text.categories', 'type': 'nested'},
#   {'field': 'extracted_metadata', 'type': 'nested'},
#   {'field': 'enriched_text.entities.disambiguation.subtype', 'type': 'string'},
#   {'field': 'enriched_text.sentiment', 'type': 'nested'},
#   {'field': 'enriched_text.entities.disambiguation.dbpedia_resource',
#    'type': 'string'},
#   {'field': 'enriched_text.sentiment.document.score', 'type': 'double'},
#   {'field': 'extracted_metadata.filename', 'type': 'string'},
#   {'field': 'enriched_text.relations.arguments.entities', 'type': 'nested'}]}

# %% [markdown]
# ### Test query
#
# Let's perform a simple query to see if the service can fetch the proper document for us:
# > _Look for all paragraphs that have a relation (sentence) with "Jar Jar" as the subject, and return the title and text._

# %%
# A simple query
results = discovery.query(environment_id=env_id, collection_id=col_id,
    query_options={
        "query": "enriched_text.relations.subject.text:\"Light Saber\"",
        "return": "metadata.title,text"
    })
print(json.dumps(results, indent=2))
# Out:
# {
#   "matching_results": 82,
#   "session_token": "1_gEryBKuNHp6ulMT2_2L6AdPLPA",
#   "results": [
#     {
#       "id": "01b224c3-d422-4875-a62d-9e252f85d454",
#       "score": 1,
#       "extracted_metadata": {
#         "sha1": "dd45b2a40d6d95e29c11d1d3f64bafe2cbff12b7",
#         "filename": "Star Wars: Episode IV - A New Hope",
#         "file_type": "json"
#       },
#       "text": "The droids are captured by Jawa traders, who sell them to moisture farmers Owen and Beru Lars and their nephew Luke Skywalker. While cleaning R2-D2, Luke accidentally triggers part of Leia's message, in which she requests help from Obi-Wan Kenobi. The next morning, Luke finds R2-D2 searching for Obi-Wan, and meets Ben Kenobi, an old hermit who lives in the hills and reveals himself to be Obi-Wan. Obi-Wan tells Luke of his days as one of the Jedi Knights, former Galactic Republic peacekeepers with supernatural powers derived from an energy called The Force, who were all but wiped out by the Empire. Contrary to his uncle's statements, Luke learns that his father, Anakin, fought alongside Obi-Wan as a Jedi Knight. Obi-Wan tells Luke that Vader was his former pupil who turned to the dark side of the Force and killed Anakin. Obi-Wan then presents to Luke his father's weapon \u2013 a lightsaber.",
#       "enriched_text": {
#         "entities": [
#           {
#             "count": 5,
#             "sentiment": {
#               "score": -0.447323,
#               "label": "negative"
#             },
#             "text": "Obi-Wan Kenobi",
#             "relevance": 0.921044,
#             "type": "Person"
#           },
#           {
#             "count": 7,
#             "sentiment": {
#               "score": -0.187867,
#               "label": "negative"
#             },
#             "text": "Luke Skywalker",
#             "relevance": 0.915654,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Beru Lars",
#             "relevance": 0.180753,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.374901,
#               "label": "negative"
#             },
#             "text": "Jawa traders",
#             "relevance": 0.179196,
#             "type": "Company"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Anakin",
#             "relevance": 0.172496,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.449284,
#               "label": "negative"
#             },
#             "text": "Galactic Republic",
#             "relevance": 0.152843,
#             "type": "Organization",
#             "disambiguation": {
#               "subtype": [],
#               "name": "Galactic Republic",
#               "dbpedia_resource": "http://dbpedia.org/resource/Galactic_Republic"
#             }
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Leia",
#             "relevance": 0.146149,
#             "type": "Person"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": -0.473289,
#               "label": "negative"
#             },
#             "text": "Vader",
#             "relevance": 0.121453,
#             "type": "Person"
#           }
#         ],
#         "sentiment": {
#           "document": {
#             "score": -0.662447,
#             "label": "negative"
#           }
#         },
#         "concepts": [
#           {
#             "text": "Jedi",
#             "relevance": 0.956841,
#             "dbpedia_resource": "http://dbpedia.org/resource/Jedi"
#           },
#           {
#             "text": "Anakin Skywalker",
#             "relevance": 0.938316,
#             "dbpedia_resource": "http://dbpedia.org/resource/Anakin_Skywalker"
#           },
#           {
#             "text": "Darth Vader",
#             "relevance": 0.930227,
#             "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#           },
#           {
#             "text": "Luke Skywalker",
#             "relevance": 0.876161,
#             "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#           },
#           {
#             "text": "Star Wars Episode IV: A New Hope",
#             "relevance": 0.864972,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope"
#           },
#           {
#             "text": "Obi-Wan Kenobi",
#             "relevance": 0.858897,
#             "dbpedia_resource": "http://dbpedia.org/resource/Obi-Wan_Kenobi"
#           },
#           {
#             "text": "Star Wars",
#             "relevance": 0.837103,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars"
#           },
#           {
#             "text": "Star Wars Episode III: Revenge of the Sith",
#             "relevance": 0.80424,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_III:_Revenge_of_the_Sith"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.578577,
#             "label": "/law, govt and politics/armed forces/army"
#           },
#           {
#             "score": 0.375552,
#             "label": "/art and entertainment/movies and tv/movies"
#           },
#           {
#             "score": 0.141714,
#             "label": "/society/unrest and war"
#           }
#         ],
#         "relations": [
#           {
#             "type": "agentOf",
#             "sentence": "The droids are captured by Jawa traders, who sell them to moisture farmers Owen and Beru Lars and their nephew Luke Skywalker.",
#             "score": 0.423086,
#             "arguments": [
#               {
#                 "text": "traders",
#                 "location": [
#                   32,
#                   39
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "traders"
#                   }
#                 ]
#               },
#               {
#                 "text": "captured",
#                 "location": [
#                   15,
#                   23
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventCustody",
#                     "text": "captured"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "parentOf",
#             "sentence": "Obi-Wan then presents to Luke his father's weapon - a lightsaber.",
#             "score": 0.754498,
#             "arguments": [
#               {
#                 "text": "father",
#                 "location": [
#                   866,
#                   872
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Anakin"
#                   }
#                 ]
#               },
#               {
#                 "text": "his",
#                 "location": [
#                   862,
#                   865
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Obi-Wan Kenobi"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "ownerOf",
#             "sentence": "Obi-Wan then presents to Luke his father's weapon - a lightsaber.",
#             "score": 0.377783,
#             "arguments": [
#               {
#                 "text": "father",
#                 "location": [
#                   866,
#                   872
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Anakin"
#                   }
#                 ]
#               },
#               {
#                 "text": "weapon",
#                 "location": [
#                   875,
#                   881
#                 ],
#                 "entities": [
#                   {
#                     "type": "Weapon",
#                     "text": "weapon"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "employedBy",
#             "sentence": "The droids are captured by Jawa traders, who sell them to moisture farmers Owen and Beru Lars and their nephew Luke Skywalker.",
#             "score": 0.383657,
#             "arguments": [
#               {
#                 "text": "traders",
#                 "location": [
#                   32,
#                   39
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "traders"
#                   }
#                 ]
#               },
#               {
#                 "text": "Jawa",
#                 "location": [
#                   27,
#                   31
#                 ],
#                 "entities": [
#                   {
#                     "type": "Organization",
#                     "text": "Jawa"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "partOfMany",
#             "sentence": "The droids are captured by Jawa traders, who sell them to moisture farmers Owen and Beru Lars and their nephew Luke Skywalker.",
#             "score": 0.928476,
#             "arguments": [
#               {
#                 "text": "Owen",
#                 "location": [
#                   75,
#                   79
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Owen"
#                   }
#                 ]
#               },
#               {
#                 "text": "farmers",
#                 "location": [
#                   67,
#                   74
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "farmers"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "partOfMany",
#             "sentence": "The droids are captured by Jawa traders, who sell them to moisture farmers Owen and Beru Lars and their nephew Luke Skywalker.",
#             "score": 0.95528,
#             "arguments": [
#               {
#                 "text": "Beru Lars",
#                 "location": [
#                   84,
#                   93
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Beru Lars"
#                   }
#                 ]
#               },
#               {
#                 "text": "farmers",
#                 "location": [
#                   67,
#                   74
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "farmers"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "partOfMany",
#             "sentence": "The droids are captured by Jawa traders, who sell them to moisture farmers Owen and Beru Lars and their nephew Luke Skywalker.",
#             "score": 0.28677,
#             "arguments": [
#               {
#                 "text": "nephew",
#                 "location": [
#                   104,
#                   110
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Luke Skywalker"
#                   }
#                 ]
#               },
#               {
#                 "text": "their",
#                 "location": [
#                   98,
#                   103
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "traders"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "agentOf",
#             "sentence": "Obi-Wan tells Luke of his days as one of the Jedi Knights, former Galactic Republic peacekeepers with supernatural powers derived from an energy called The Force, who were all but wiped out by the Empire.",
#             "score": 0.998,
#             "arguments": [
#               {
#                 "text": "Obi-Wan",
#                 "location": [
#                   400,
#                   407
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Obi-Wan Kenobi"
#                   }
#                 ]
#               },
#               {
#                 "text": "tells",
#                 "location": [
#                   408,
#                   413
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventCommunication",
#                     "text": "tells"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "agentOf",
#             "sentence": "Obi-Wan tells Luke that Vader was his former pupil who turned to the dark side of the Force and killed Anakin.",
#             "score": 0.992934,
#             "arguments": [
#               {
#                 "text": "Obi-Wan",
#                 "location": [
#                   721,
#                   728
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Obi-Wan Kenobi"
#                   }
#                 ]
#               },
#               {
#                 "text": "tells",
#                 "location": [
#                   729,
#                   734
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventCommunication",
#                     "text": "tells"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "affectedBy",
#             "sentence": "Obi-Wan tells Luke of his days as one of the Jedi Knights, former Galactic Republic peacekeepers with supernatural powers derived from an energy called The Force, who were all but wiped out by the Empire.",
#             "score": 0.916099,
#             "arguments": [
#               {
#                 "text": "Luke",
#                 "location": [
#                   414,
#                   418
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Luke Skywalker"
#                   }
#                 ]
#               },
#               {
#                 "text": "tells",
#                 "location": [
#                   408,
#                   413
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventCommunication",
#                     "text": "tells"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "affectedBy",
#             "sentence": "Obi-Wan tells Luke that Vader was his former pupil who turned to the dark side of the Force and killed Anakin.",
#             "score": 0.916099,
#             "arguments": [
#               {
#                 "text": "Luke",
#                 "location": [
#                   735,
#                   739
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Luke Skywalker"
#                   }
#                 ]
#               },
#               {
#                 "text": "tells",
#                 "location": [
#                   729,
#                   734
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventCommunication",
#                     "text": "tells"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "agentOf",
#             "sentence": "Contrary to his uncle's statements, Luke learns that his father, Anakin, fought alongside Obi-Wan as a Jedi Knight.",
#             "score": 0.997494,
#             "arguments": [
#               {
#                 "text": "Luke",
#                 "location": [
#                   641,
#                   645
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Luke Skywalker"
#                   }
#                 ]
#               },
#               {
#                 "text": "learns",
#                 "location": [
#                   646,
#                   652
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventCommunication",
#                     "text": "learns"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "parentOf",
#             "sentence": "Contrary to his uncle's statements, Luke learns that his father, Anakin, fought alongside Obi-Wan as a Jedi Knight.",
#             "score": 0.64847,
#             "arguments": [
#               {
#                 "text": "father",
#                 "location": [
#                   662,
#                   668
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Anakin"
#                   }
#                 ]
#               },
#               {
#                 "text": "his",
#                 "location": [
#                   658,
#                   661
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Ben Kenobi"
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "keywords": [
#           {
#             "text": "Obi-Wan tells Luke",
#             "relevance": 0.970736
#           },
#           {
#             "text": "nephew Luke Skywalker",
#             "relevance": 0.841949
#           },
#           {
#             "text": "Obi-Wan Kenobi",
#             "relevance": 0.810236
#           },
#           {
#             "text": "Galactic Republic peacekeepers",
#             "relevance": 0.671881
#           },
#           {
#             "text": "Beru Lars",
#             "relevance": 0.592325
#           },
#           {
#             "text": "Ben Kenobi",
#             "relevance": 0.582091
#           },
#           {
#             "text": "Jawa traders",
#             "relevance": 0.573486
#           },
#           {
#             "text": "farmers Owen",
#             "relevance": 0.561412
#           },
#           {
#             "text": "Jedi Knights",
#             "relevance": 0.549498
#           },
#           {
#             "text": "old hermit",
#             "relevance": 0.543809
#           },
#           {
#             "text": "supernatural powers",
#             "relevance": 0.542963
#           },
#           {
#             "text": "Jedi Knight",
#             "relevance": 0.542843
#           },
#           {
#             "text": "R2-D2",
#             "relevance": 0.504194
#           },
#           {
#             "text": "Anakin",
#             "relevance": 0.47753
#           },
#           {
#             "text": "father",
#             "relevance": 0.452143
#           },
#           {
#             "text": "droids",
#             "relevance": 0.445824
#           },
#           {
#             "text": "Force",
#             "relevance": 0.443184
#           },
#           {
#             "text": "Leia",
#             "relevance": 0.4405
#           },
#           {
#             "text": "lightsaber",
#             "relevance": 0.440307
#           },
#           {
#             "text": "Vader",
#             "relevance": 0.433381
#           },
#           {
#             "text": "pupil",
#             "relevance": 0.432578
#           },
#           {
#             "text": "uncle",
#             "relevance": 0.428533
#           },
#           {
#             "text": "weapon",
#             "relevance": 0.427452
#           },
#           {
#             "text": "morning",
#             "relevance": 0.425826
#           },
#           {
#             "text": "message",
#             "relevance": 0.42426
#           },
#           {
#             "text": "help",
#             "relevance": 0.424168
#           },
#           {
#             "text": "hills",
#             "relevance": 0.423395
#           }
#         ]
#       }
#     },
#     {
#       "id": "7acb01a8-629c-42b0-81ad-3b9c4c56b944",
#       "score": 1,
#       "extracted_metadata": {
#         "sha1": "79db598d94fb7a9a76eda47a3d6f502054fd610e",
#         "filename": "Star Wars: Episode IV - A New Hope",
#         "file_type": "json"
#       },
#       "text": "The Rebels analyze the Death Star's plans and identify a vulnerable exhaust port that connects to the station's main reactor. Luke joins the Rebel assault squadron, while Han collects his payment for the transport and intends to leave, despite Luke's request that he stay and help. In the ensuing battle, the Rebels suffer heavy losses after several unsuccessful attack runs, leaving Luke as one of the few surviving pilots. Vader leads a squadron of TIE fighters and prepares to attack Luke's X-wing fighter, but Han returns and fires on the Imperials, sending Vader spiraling away. Helped by guidance from Obi-Wan's spirit, Luke uses the Force and successfully destroys the Death Star seconds before it can fire on the Rebel base. Back on Yavin IV, Leia awards Luke and Han with medals for their heroism.",
#       "enriched_text": {
#         "entities": [
#           {
#             "count": 7,
#             "sentiment": {
#               "score": -0.333049,
#               "label": "negative"
#             },
#             "text": "Luke",
#             "relevance": 0.936683,
#             "type": "Person"
#           },
#           {
#             "count": 3,
#             "sentiment": {
#               "score": -0.233801,
#               "label": "negative"
#             },
#             "text": "Han",
#             "relevance": 0.476328,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Rebel assault squadron",
#             "relevance": 0.352251,
#             "type": "Organization"
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Rebels",
#             "relevance": 0.348799,
#             "type": "Organization",
#             "disambiguation": {
#               "subtype": [],
#               "name": "Rebel Alliance",
#               "dbpedia_resource": "http://dbpedia.org/resource/Rebel_Alliance"
#             }
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": -0.567802,
#               "label": "negative"
#             },
#             "text": "Vader",
#             "relevance": 0.241565,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0.407984,
#               "label": "positive"
#             },
#             "text": "Obi-Wan",
#             "relevance": 0.187566,
#             "type": "Person"
#           }
#         ],
#         "sentiment": {
#           "document": {
#             "score": -0.627648,
#             "label": "negative"
#           }
#         },
#         "concepts": [
#           {
#             "text": "Star Wars Episode IV: A New Hope",
#             "relevance": 0.943183,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope"
#           },
#           {
#             "text": "Rebel Alliance",
#             "relevance": 0.935126,
#             "dbpedia_resource": "http://dbpedia.org/resource/Rebel_Alliance"
#           },
#           {
#             "text": "Darth Vader",
#             "relevance": 0.933122,
#             "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#           },
#           {
#             "text": "Luke Skywalker",
#             "relevance": 0.861567,
#             "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#           },
#           {
#             "text": "Star Wars",
#             "relevance": 0.686437,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars"
#           },
#           {
#             "text": "Star Wars Episode III: Revenge of the Sith",
#             "relevance": 0.610595,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_III:_Revenge_of_the_Sith"
#           },
#           {
#             "text": "Star Wars Episode VI: Return of the Jedi",
#             "relevance": 0.591454,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi"
#           },
#           {
#             "text": "Obi-Wan Kenobi",
#             "relevance": 0.581634,
#             "dbpedia_resource": "http://dbpedia.org/resource/Obi-Wan_Kenobi"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.420587,
#             "label": "/art and entertainment/music/recording industry/music awards"
#           },
#           {
#             "score": 0.34986,
#             "label": "/law, govt and politics/armed forces/army"
#           },
#           {
#             "score": 0.349328,
#             "label": "/travel/transports/air travel/helicopters"
#           }
#         ],
#         "relations": [
#           {
#             "type": "awardedTo",
#             "sentence": "The Rebels analyze the Death Star's plans and identify a vulnerable exhaust port that connects to the station's main reactor.",
#             "score": 0.459805,
#             "arguments": [
#               {
#                 "text": "Death Star",
#                 "location": [
#                   23,
#                   33
#                 ],
#                 "entities": [
#                   {
#                     "type": "EntertainmentAward",
#                     "text": "Death Star"
#                   }
#                 ]
#               },
#               {
#                 "text": "Rebels",
#                 "location": [
#                   4,
#                   10
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "fighters"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "awardedTo",
#             "sentence": "Back on Yavin IV, Leia awards Luke and Han with medals for their heroism.",
#             "score": 0.405189,
#             "arguments": [
#               {
#                 "text": "medals",
#                 "location": [
#                   781,
#                   787
#                 ],
#                 "entities": [
#                   {
#                     "type": "EntertainmentAward",
#                     "text": "Death Star"
#                   }
#                 ]
#               },
#               {
#                 "text": "their",
#                 "location": [
#                   792,
#                   797
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "fighters"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "awardedTo",
#             "sentence": "Back on Yavin IV, Leia awards Luke and Han with medals for their heroism.",
#             "score": 0.512726,
#             "arguments": [
#               {
#                 "text": "medals",
#                 "location": [
#                   781,
#                   787
#                 ],
#                 "entities": [
#                   {
#                     "type": "EntertainmentAward",
#                     "text": "Death Star"
#                   }
#                 ]
#               },
#               {
#                 "text": "Han",
#                 "location": [
#                   772,
#                   775
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Han"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "partOfMany",
#             "sentence": "Back on Yavin IV, Leia awards Luke and Han with medals for their heroism.",
#             "score": 0.962857,
#             "arguments": [
#               {
#                 "text": "Han",
#                 "location": [
#                   772,
#                   775
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Han"
#                   }
#                 ]
#               },
#               {
#                 "text": "their",
#                 "location": [
#                   792,
#                   797
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "fighters"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "agentOf",
#             "sentence": "Luke joins the Rebel assault squadron, while Han collects his payment for the transport and intends to leave, despite Luke's request that he stay and help.",
#             "score": 0.580637,
#             "arguments": [
#               {
#                 "text": "Luke",
#                 "location": [
#                   126,
#                   130
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Luke"
#                   }
#                 ]
#               },
#               {
#                 "text": "joins",
#                 "location": [
#                   131,
#                   136
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventPersonnel",
#                     "text": "joins"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "agentOf",
#             "sentence": "Luke joins the Rebel assault squadron, while Han collects his payment for the transport and intends to leave, despite Luke's request that he stay and help.",
#             "score": 0.835217,
#             "arguments": [
#               {
#                 "text": "Rebel",
#                 "location": [
#                   141,
#                   146
#                 ],
#                 "entities": [
#                   {
#                     "type": "Organization",
#                     "text": "Rebel"
#                   }
#                 ]
#               },
#               {
#                 "text": "assault",
#                 "location": [
#                   147,
#                   154
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventViolence",
#                     "text": "assault"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "agentOf",
#             "sentence": "Luke joins the Rebel assault squadron, while Han collects his payment for the transport and intends to leave, despite Luke's request that he stay and help.",
#             "score": 0.995735,
#             "arguments": [
#               {
#                 "text": "Luke",
#                 "location": [
#                   244,
#                   248
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Luke"
#                   }
#                 ]
#               },
#               {
#                 "text": "request",
#                 "location": [
#                   251,
#                   258
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventCommunication",
#                     "text": "request"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "partOfMany",
#             "sentence": "In the ensuing battle, the Rebels suffer heavy losses after several unsuccessful attack runs, leaving Luke as one of the few surviving pilots.",
#             "score": 0.785472,
#             "arguments": [
#               {
#                 "text": "one",
#                 "location": [
#                   392,
#                   395
#                 ],
#                 "entities": [
#                   {
#                     "type": "Cardinal",
#                     "text": "one"
#                   }
#                 ]
#               },
#               {
#                 "text": "pilots",
#                 "location": [
#                   417,
#                   423
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "pilots"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "awardedBy",
#             "sentence": "Helped by guidance from Obi-Wan's spirit, Luke uses the Force and successfully destroys the Death Star seconds before it can fire on the Rebel base.",
#             "score": 0.444822,
#             "arguments": [
#               {
#                 "text": "Death Star",
#                 "location": [
#                   676,
#                   686
#                 ],
#                 "entities": [
#                   {
#                     "type": "EntertainmentAward",
#                     "text": "Death Star"
#                   }
#                 ]
#               },
#               {
#                 "text": "Force",
#                 "location": [
#                   640,
#                   645
#                 ],
#                 "entities": [
#                   {
#                     "type": "Organization",
#                     "text": "Force"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "partOfMany",
#             "sentence": "Back on Yavin IV, Leia awards Luke and Han with medals for their heroism.",
#             "score": 0.909434,
#             "arguments": [
#               {
#                 "text": "Yavin IV",
#                 "location": [
#                   741,
#                   749
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Yavin IV"
#                   }
#                 ]
#               },
#               {
#                 "text": "their",
#                 "location": [
#                   792,
#                   797
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "fighters"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "partOfMany",
#             "sentence": "Back on Yavin IV, Leia awards Luke and Han with medals for their heroism.",
#             "score": 0.989563,
#             "arguments": [
#               {
#                 "text": "Leia",
#                 "location": [
#                   751,
#                   755
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Leia"
#                   }
#                 ]
#               },
#               {
#                 "text": "their",
#                 "location": [
#                   792,
#                   797
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "fighters"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "partOfMany",
#             "sentence": "Back on Yavin IV, Leia awards Luke and Han with medals for their heroism.",
#             "score": 0.981124,
#             "arguments": [
#               {
#                 "text": "Luke",
#                 "location": [
#                   763,
#                   767
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Luke"
#                   }
#                 ]
#               },
#               {
#                 "text": "their",
#                 "location": [
#                   792,
#                   797
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "fighters"
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "keywords": [
#           {
#             "text": "Rebel assault squadron",
#             "relevance": 0.939948
#           },
#           {
#             "text": "vulnerable exhaust port",
#             "relevance": 0.93859
#           },
#           {
#             "text": "unsuccessful attack runs",
#             "relevance": 0.851579
#           },
#           {
#             "text": "Luke",
#             "relevance": 0.83867
#           },
#           {
#             "text": "Death Star",
#             "relevance": 0.817913
#           },
#           {
#             "text": "Han returns",
#             "relevance": 0.559279
#           },
#           {
#             "text": "main reactor",
#             "relevance": 0.505278
#           },
#           {
#             "text": "X-wing fighter",
#             "relevance": 0.459347
#           },
#           {
#             "text": "heavy losses",
#             "relevance": 0.450044
#           },
#           {
#             "text": "TIE fighters",
#             "relevance": 0.449965
#           },
#           {
#             "text": "Rebel base",
#             "relevance": 0.443575
#           },
#           {
#             "text": "Rebels",
#             "relevance": 0.265674
#           },
#           {
#             "text": "Vader",
#             "relevance": 0.232761
#           }
#         ]
#       }
#     },
#     {
#       "id": "cb842477-6ce0-4095-a9c6-2fca2f50e50c",
#       "score": 1,
#       "extracted_metadata": {
#         "sha1": "e2fe03994f2e0afac08f19527630880077aab7be",
#         "filename": "Star Wars: Episode VI - Return of the Jedi",
#         "file_type": "json"
#       },
#       "text": "Vader takes Luke to the Death Star to meet the Emperor, intent on turning him to the dark side. The Emperor reveals that the Death Star is actually fully operational and the Rebel fleet will fall into a trap. On Endor, Han's strike team is captured by Imperial forces, but a surprise counterattack by the Ewoks allows the Rebels to battle the Imperials. Meanwhile, Lando, piloting the Millennium Falcon, leads the Rebel fleet to the Death Star, only to find that the station's shield is still active and the Imperial fleet is waiting for them. The Emperor tempts Luke to give in to his anger and join the dark side of the Force, and Luke engages Vader in a lightsaber duel. Vader senses that Luke has a sister, and threatens to turn her to the dark side. Enraged, Luke attacks Vader and severs his father's prosthetic right hand. The Emperor entreats Luke to kill Vader and take his place, but Luke refuses, declaring himself a Jedi as his father had been. On Endor, the strike team defeats the Imperial forces and destroys the shield generator, allowing the Rebel fleet to launch their assault on the Death Star. At the same time, a furious Palpatine tortures Luke with Force lightning. Unwilling to let his son die, Vader kills the Emperor but is mortally wounded in the process. He asks Luke to help remove his mask before dying in Luke's arms.",
#       "enriched_text": {
#         "entities": [
#           {
#             "count": 11,
#             "sentiment": {
#               "score": -0.563762,
#               "label": "negative"
#             },
#             "text": "Luke",
#             "relevance": 0.881994,
#             "type": "Person"
#           },
#           {
#             "count": 6,
#             "sentiment": {
#               "score": -0.643797,
#               "label": "negative"
#             },
#             "text": "Vader",
#             "relevance": 0.652257,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.259909,
#               "label": "negative"
#             },
#             "text": "Rebels",
#             "relevance": 0.163859,
#             "type": "Organization",
#             "disambiguation": {
#               "subtype": [],
#               "name": "Rebel Alliance",
#               "dbpedia_resource": "http://dbpedia.org/resource/Rebel_Alliance"
#             }
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Lando",
#             "relevance": 0.159133,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Han",
#             "relevance": 0.151732,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.492776,
#               "label": "negative"
#             },
#             "text": "Palpatine",
#             "relevance": 0.150524,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.330147,
#               "label": "negative"
#             },
#             "text": "assault",
#             "relevance": 0.143127,
#             "type": "Crime"
#           }
#         ],
#         "sentiment": {
#           "document": {
#             "score": -0.694319,
#             "label": "negative"
#           }
#         },
#         "concepts": [
#           {
#             "text": "Darth Vader",
#             "relevance": 0.98848,
#             "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#           },
#           {
#             "text": "Star Wars Episode VI: Return of the Jedi",
#             "relevance": 0.903393,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi"
#           },
#           {
#             "text": "Luke Skywalker",
#             "relevance": 0.896572,
#             "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#           },
#           {
#             "text": "Star Wars Episode III: Revenge of the Sith",
#             "relevance": 0.793941,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_III:_Revenge_of_the_Sith"
#           },
#           {
#             "text": "Star Wars Episode IV: A New Hope",
#             "relevance": 0.783218,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope"
#           },
#           {
#             "text": "Star Wars Episode V: The Empire Strikes Back",
#             "relevance": 0.770864,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back"
#           },
#           {
#             "text": "Obi-Wan Kenobi",
#             "relevance": 0.759084,
#             "dbpedia_resource": "http://dbpedia.org/resource/Obi-Wan_Kenobi"
#           },
#           {
#             "text": "Star Wars",
#             "relevance": 0.725623,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.490846,
#             "label": "/society/unrest and war"
#           },
#           {
#             "score": 0.439744,
#             "label": "/law, govt and politics/armed forces/army"
#           },
#           {
#             "score": 0.381615,
#             "label": "/shopping/toys/action figures"
#           }
#         ],
#         "relations": [
#           {
#             "type": "awardedTo",
#             "sentence": "Vader takes Luke to the Death Star to meet the Emperor, intent on turning him to the dark side.",
#             "score": 0.555952,
#             "arguments": [
#               {
#                 "text": "Death Star",
#                 "location": [
#                   24,
#                   34
#                 ],
#                 "entities": [
#                   {
#                     "type": "EntertainmentAward",
#                     "text": "Death Star"
#                   }
#                 ]
#               },
#               {
#                 "text": "Luke",
#                 "location": [
#                   12,
#                   16
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Palpatine tortures Luke"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "agentOf",
#             "sentence": "Enraged, Luke attacks Vader and severs his father's prosthetic right hand.",
#             "score": 0.560682,
#             "arguments": [
#               {
#                 "text": "Luke",
#                 "location": [
#                   764,
#                   768
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Palpatine tortures Luke"
#                   }
#                 ]
#               },
#               {
#                 "text": "attacks",
#                 "location": [
#                   769,
#                   776
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventViolence",
#                     "text": "attacks"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "affectedBy",
#             "sentence": "Enraged, Luke attacks Vader and severs his father's prosthetic right hand.",
#             "score": 0.762475,
#             "arguments": [
#               {
#                 "text": "Vader",
#                 "location": [
#                   777,
#                   782
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Vader senses"
#                   }
#                 ]
#               },
#               {
#                 "text": "attacks",
#                 "location": [
#                   769,
#                   776
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventViolence",
#                     "text": "attacks"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "parentOf",
#             "sentence": "Enraged, Luke attacks Vader and severs his father's prosthetic right hand.",
#             "score": 0.630643,
#             "arguments": [
#               {
#                 "text": "father",
#                 "location": [
#                   798,
#                   804
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Palpatine tortures Luke"
#                   }
#                 ]
#               },
#               {
#                 "text": "his",
#                 "location": [
#                   794,
#                   797
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Vader senses"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "parentOf",
#             "sentence": "The Emperor entreats Luke to kill Vader and take his place, but Luke refuses, declaring himself a Jedi as his father had been.",
#             "score": 0.660361,
#             "arguments": [
#               {
#                 "text": "father",
#                 "location": [
#                   940,
#                   946
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Palpatine tortures Luke"
#                   }
#                 ]
#               },
#               {
#                 "text": "his",
#                 "location": [
#                   936,
#                   939
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Vader senses"
#                   }
#                 ]
# ...
#             "score": 0.704501,
#             "arguments": [
#               {
#                 "text": "Jedi Temple",
#                 "location": [
#                   1172,
#                   1183
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Jedi Temple"
#                   }
#                 ]
#               },
#               {
#                 "text": "everyone",
#                 "location": [
#                   1156,
#                   1164
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "everyone"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "partOfMany",
#             "sentence": "Vader massacres the remaining Separatist leaders hiding on the volcanic planet Mustafar, while Palpatine addresses the Galactic Senate, transforming the Republic into the Galactic Empire and declaring himself Emperor.",
#             "score": 0.658584,
#             "arguments": [
#               {
#                 "text": "leaders",
#                 "location": [
#                   1226,
#                   1233
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "leaders"
#                   }
#                 ]
#               },
#               {
#                 "text": "Separatist",
#                 "location": [
#                   1215,
#                   1225
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Separatist"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "locatedAt",
#             "sentence": "Vader massacres the remaining Separatist leaders hiding on the volcanic planet Mustafar, while Palpatine addresses the Galactic Senate, transforming the Republic into the Galactic Empire and declaring himself Emperor.",
#             "score": 0.512362,
#             "arguments": [
#               {
#                 "text": "planet",
#                 "location": [
#                   1257,
#                   1263
#                 ],
#                 "entities": [
#                   {
#                     "type": "GeopoliticalEntity",
#                     "text": "Mustafar"
#                   }
#                 ]
#               },
#               {
#                 "text": "volcanic",
#                 "location": [
#                   1248,
#                   1256
#                 ],
#                 "entities": [
#                   {
#                     "type": "GeographicFeature",
#                     "text": "volcanic"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "employedBy",
#             "sentence": "Vader massacres the remaining Separatist leaders hiding on the volcanic planet Mustafar, while Palpatine addresses the Galactic Senate, transforming the Republic into the Galactic Empire and declaring himself Emperor.",
#             "score": 0.688223,
#             "arguments": [
#               {
#                 "text": "Palpatine",
#                 "location": [
#                   1280,
#                   1289
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Palpatine tantalizes Anakin"
#                   }
#                 ]
#               },
#               {
#                 "text": "Senate",
#                 "location": [
#                   1313,
#                   1319
#                 ],
#                 "entities": [
#                   {
#                     "type": "Organization",
#                     "text": "Senate",
#                     "disambiguation": {
#                       "subtype": [
#                         "Government"
#                       ]
#                     }
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "partOf",
#             "sentence": "Vader massacres the remaining Separatist leaders hiding on the volcanic planet Mustafar, while Palpatine addresses the Galactic Senate, transforming the Republic into the Galactic Empire and declaring himself Emperor.",
#             "score": 0.564988,
#             "arguments": [
#               {
#                 "text": "Galactic Empire",
#                 "location": [
#                   1356,
#                   1371
#                 ],
#                 "entities": [
#                   {
#                     "type": "Organization",
#                     "text": "Galactic Empire"
#                   }
#                 ]
#               },
#               {
#                 "text": "Republic",
#                 "location": [
#                   1338,
#                   1346
#                 ],
#                 "entities": [
#                   {
#                     "type": "GeopoliticalEntity",
#                     "text": "Republic",
#                     "disambiguation": {
#                       "subtype": [
#                         "Country"
#                       ]
#                     }
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "agentOf",
#             "sentence": "Vader massacres the remaining Separatist leaders hiding on the volcanic planet Mustafar, while Palpatine addresses the Galactic Senate, transforming the Republic into the Galactic Empire and declaring himself Emperor.",
#             "score": 0.509503,
#             "arguments": [
#               {
#                 "text": "himself",
#                 "location": [
#                   1386,
#                   1393
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Palpatine tantalizes Anakin"
#                   }
#                 ]
#               },
#               {
#                 "text": "declaring",
#                 "location": [
#                   1376,
#                   1385
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventCommunication",
#                     "text": "declaring"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "residesIn",
#             "sentence": "Having survived the chaos, Obi-Wan and Yoda return to Coruscant and learn of Anakin's treachery.",
#             "score": 0.387704,
#             "arguments": [
#               {
#                 "text": "Yoda",
#                 "location": [
#                   1442,
#                   1446
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Yoda"
#                   }
#                 ]
#               },
#               {
#                 "text": "Coruscant",
#                 "location": [
#                   1457,
#                   1466
#                 ],
#                 "entities": [
#                   {
#                     "type": "GeopoliticalEntity",
#                     "text": "Coruscant"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "agentOf",
#             "sentence": "Palpatine appoints Anakin to the Jedi Council as his representative, but the Council declines to grant Anakin the rank of Jedi Master and orders him to spy on Palpatine, causing Anakin's faith in the Jedi to diminish significantly.",
#             "score": 0.699931,
#             "arguments": [
#               {
#                 "text": "him",
#                 "location": [
#                   145,
#                   148
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "his"
#                   }
#                 ]
#               },
#               {
#                 "text": "orders",
#                 "location": [
#                   138,
#                   144
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventCommunication",
#                     "text": "orders"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "partOfMany",
#             "sentence": "Palpatine tantalizes Anakin with secret knowledge of the dark side of the Force, including the power to save his loved ones from dying.",
#             "score": 0.721453,
#             "arguments": [
#               {
#                 "text": "Palpatine tantalizes Anakin",
#                 "location": [
#                   232,
#                   259
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Palpatine tantalizes Anakin"
#                   }
#                 ]
#               },
#               {
#                 "text": "ones",
#                 "location": [
#                   351,
#                   355
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "ones"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "agentOf",
#             "sentence": "Tempting Anakin, Palpatine eventually reveals that he is the Sith Lord Darth Sidious, saying that only he has the knowledge to save Padm\u00e9 from dying.",
#             "score": 0.681935,
#             "arguments": [
#               {
#                 "text": "Palpatine",
#                 "location": [
#                   529,
#                   538
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Palpatine tantalizes Anakin"
#                   }
#                 ]
#               },
#               {
#                 "text": "reveals",
#                 "location": [
#                   550,
#                   557
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventCommunication",
#                     "text": "reveals"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "agentOf",
#             "sentence": "Tempting Anakin, Palpatine eventually reveals that he is the Sith Lord Darth Sidious, saying that only he has the knowledge to save Padm\u00e9 from dying.",
#             "score": 0.784002,
#             "arguments": [
#               {
#                 "text": "he",
#                 "location": [
#                   563,
#                   565
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "his"
#                   }
#                 ]
#               },
#               {
#                 "text": "saying",
#                 "location": [
#                   598,
#                   604
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventCommunication",
#                     "text": "saying"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "agentOf",
#             "sentence": "Anakin reports Palpatine's treachery to Mace Windu, who confronts and subdues the Sith Lord, severely disfiguring him in the process.",
#             "score": 0.999017,
#             "arguments": [
#               {
#                 "text": "Anakin",
#                 "location": [
#                   662,
#                   668
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Palpatine tantalizes Anakin"
#                   }
#                 ]
#               },
#               {
#                 "text": "reports",
#                 "location": [
#                   669,
#                   676
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventCommunication",
#                     "text": "reports"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "agentOf",
#             "sentence": "Anakin pledges himself to Palpatine, who dubs him Darth Vader.",
#             "score": 0.999042,
#             "arguments": [
#               {
#                 "text": "Anakin",
#                 "location": [
#                   955,
#                   961
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Palpatine tantalizes Anakin"
#                   }
#                 ]
#               },
#               {
#                 "text": "pledges",
#                 "location": [
#                   962,
#                   969
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventCommunication",
#                     "text": "pledges"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "affectedBy",
#             "sentence": "Anakin pledges himself to Palpatine, who dubs him Darth Vader.",
#             "score": 0.648081,
#             "arguments": [
#               {
#                 "text": "himself",
#                 "location": [
#                   970,
#                   977
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Palpatine tantalizes Anakin"
#                   }
#                 ]
#               },
#               {
#                 "text": "pledges",
#                 "location": [
#                   962,
#                   969
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventCommunication",
#                     "text": "pledges"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "partOfMany",
#             "sentence": "Palpatine issues an order for the clone troopers to kill their Jedi commanders and dispatches Vader along with a legion of clones to kill everyone in the Jedi Temple.",
#             "score": 0.471997,
#             "arguments": [
#               {
#                 "text": "Vader",
#                 "location": [
#                   1112,
#                   1117
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Darth Vader"
#                   }
#                 ]
#               },
#               {
#                 "text": "everyone",
#                 "location": [
#                   1156,
#                   1164
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "everyone"
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "keywords": [
#           {
#             "text": "Palpatine appoints Anakin",
#             "relevance": 0.951434
#           },
#           {
#             "text": "Palpatine issues",
#             "relevance": 0.430532
#           },
#           {
#             "text": "Sith Lord",
#             "relevance": 0.314066
#           },
#           {
#             "text": "Sith Lord Darth",
#             "relevance": 0.308548
#           },
#           {
#             "text": "volcanic planet Mustafar",
#             "relevance": 0.24645
#           },
#           {
#             "text": "Jedi Master",
#             "relevance": 0.237065
#           },
#           {
#             "text": "Jedi Council",
#             "relevance": 0.232975
#           },
#           {
#             "text": "Jedi commanders",
#             "relevance": 0.201157
#           }
#         ]
#       }
#     }
#   ]
# }

# %% [markdown]
# Change the above query and see what results you get! Try to find one that returns relevant results, and keep that (along with the output) for review.
#
# > See [Query building reference](https://www.ibm.com/watson/developercloud/doc/discovery/query-reference.html) for descriptions of all possible parameters, operators and aggregations. You can also choose to build the query using the web interface (click the "Story Chunks" collection to query it), and then reproduce the query here.
#
# Then answer the questions below:
#
# **Q**: What query did you try? Express it in plain words below.
#
# **A**: Light Saber
#
#
# **Q**: What answer did you get back from Watson? You only need to mention the relevant snippet of text from the paragraph(s) returned.
#
# **A**:
#
#        "text": "Obi-Wan Kenobi",
#        "relevance": 0.921044,
#        "type": "Person"
#
#        "text": "Luke Skywalker",
#        "relevance": 0.915654,
#        "type": "Person"

# %% [markdown]
# ## 3. Parse natural language questions
#
# In order to understand questions posed in natural language, we'll use another Watson service called [Conversation](https://www.ibm.com/watson/developercloud/doc/conversation/index.html). It can be used to design conversational agents or _chatbots_ that exhibit complex behavior, but for the purpose of this project, we'll only use it to parse certain kinds of queries.
#
# ### Create a Conversation service instance
#
# Just like you did for the Discovery service, create an instance of the Conversation service. Then launch the associated tool from the service dashboard.
#
# <img src="images/conversation-tooling.png" alt="Conversation service - Tool homepage" width="800" />
#
# A _workspace_ allows you to keep all the items you need for a particular application in one place, just like an _environment_ in case of the Discovery service. Create one called "Bookworm" with a suitable description, such as "I know a lot of stories. Ask me a question!"
#
# <img src="images/conversation-workspace.png" alt="Conversation service - Blank workspace" width="800" />
#
# This should open up a blank workspace, where you can add intents, define the entities you want the agent to idenitfy and structure the overall dialog.
#
# ### Add intents
#
# An _intent_ is the goal or purpose of a user's input. Create a set of intents (at least 3) that capture the different kinds of questions that you want the system to answer, e.g. _who_, _what_ and _where_. Along with each intent, add a list of user examples or _utterances_ that map to that intent.
#
# For instance, you could enter the following examples for the _where_ intent:
#
# - Where is the Jedi temple located?
# - Where was Luke born?
#
# The Conversation service recommends at least 5 examples for each intent so that Watson learns how to recognize it. These don't have to be very precise, but more examples the better.
#
# <img src="images/conversation-intents.png" alt="Conversation service - Intents listed" width="800" />
#
# Feel free to create your own intents, based on the kinds of questions you want the system to answer, e.g. "How many ...", "What are the most common ..." etc. Each intent will need to be mapped to an appropriate query.
#
# > See [**Defining intents**](https://www.ibm.com/watson/developercloud/doc/conversation/intents.html) for a helpful video and further instructions.
#
# **Q**: What intents did you add to the Conversation service instance?
#
# **A**: what, when, where
#
#
#
# **Q**: Pick one of these intents, and list at least 5 examples for the intent that you entered.
#
# **A**:
# what did R2D2  carry by leia?
# what did vader say to luke?
# what is the force?
# what makes part of a light saber?
# what yoda taught to luke?
#
#
#
# ### Add entities
#
# Once you have your intents set, let's tell the service what entities we want it to identify. One way to do this is using the tool interface, and entering them one-by-one.
#
# > Go to [**Defining entities**](https://www.ibm.com/watson/developercloud/doc/conversation/entities.html) to see how that is done.
#
# But that can be tedious! So let's refer back to the entities that the Discovery service identified, and load them in programmatically.
#
# As before, let's connect to the Conversation service first. Remember to enter your service credentials below.

# %%
# Connect to the Conversation service instance
# TODO: Enter your username and password from the Service Credentials tab in service-credentials.json
conversation_creds = helper.fetch_credentials('conversation')
conversation = watson_developer_cloud.ConversationV1(
    version='2017-02-03',
    username=conversation_creds['username'],
    password=conversation_creds['password'])

# %% [markdown]
# Fetch the workspace you just created called "Bookworm".

# %%
wrk, wrk_id = helper.fetch_object(conversation, "workspace", "Bookworm")
print(json.dumps(wrk, indent=2))
# Out:
# Found workspace: Bookworm (8b134fe1-559c-4185-a5d1-8d510272153e)
# {
#   "name": "Bookworm",
#   "created": "2018-08-21T12:27:04.435Z",
#   "updated": "2018-08-21T12:51:38.155Z",
#   "language": "en",
#   "metadata": null,
#   "description": "The bookworm example at Udacity's NLP course.",
#   "workspace_id": "8b134fe1-559c-4185-a5d1-8d510272153e",
#   "system_settings": {
#     "tooling": {
#       "store_generic_responses": true
#     },
#     "disambiguation": {
#       "prompt": "Did you mean:",
#       "none_of_the_above_prompt": "None of the above"
#     },
#     "human_agent_assist": {
#       "prompt": "Did you mean:"
#     }
#   },
#   "learning_opt_out": false,
#   "status": "Available"
# }

# %% [markdown]
# Collect all the entities from the Discovery service collection.

# %%
# Get all the entities from the collection and group them by type
response = discovery.query(environment_id=env_id, collection_id=col_id,
    query_options={
        "return": "enriched_text.entities.type,enriched_text.entities.text"
    })

# Group individual entities by type ("Person", "Location", etc.)
entities_by_type = {}
for document in response["results"]:
    for entity in document["enriched_text"]["entities"]:
        if entity["type"] not in entities_by_type:
            entities_by_type[entity["type"]] = set()
        entities_by_type[entity["type"]].add(entity["text"])

# Ignore case to avoid duplicates
for entity_type in entities_by_type:
    entities_by_type[entity_type] = {
        e.lower(): e for e in entities_by_type[entity_type]
    }.values()

# Restructure for loading into Conversation workspace
entities_grouped = [{
    "entity": entity_type,
    "values": [{"value": entity} for entity in entities]}
        for entity_type, entities in entities_by_type.items()]
entities_grouped
# Out:
# [{'entity': 'Person',
#   'values': [{'value': 'Dagobah'},
#    {'value': 'Luke'},
#    {'value': 'Beru Lars'},
#    {'value': 'Palpatine'},
#    {'value': 'Han'},
#    {'value': 'Obi-Wan'},
#    {'value': 'Anakin'},
#    {'value': 'Vader'},
#    {'value': 'Luke Skywalker'},
#    {'value': 'Lando Calrissian'},
#    {'value': 'Leia'},
#    {'value': 'Darth Vader'},
#    {'value': 'Lando'},
#    {'value': 'Anakin Skywalker'},
#    {'value': 'Emperor Palpatine'},
#    {'value': 'Obi-Wan Kenobi'},
#    {'value': 'Boba Fett'},
#    {'value': 'Princess Leia'},
#    {'value': 'Wookiee'}]},
#  {'entity': 'Organization',
#   'values': [{'value': 'Rebel assault squadron'},
#    {'value': 'Rebels'},
#    {'value': 'Rebel Alliance'},
#    {'value': 'Galactic Republic'}]},
#  {'entity': 'Location',
#   'values': [{'value': 'Alderaan'},
#    {'value': 'Dagobah'},
#    {'value': 'Sarlacc'}]},
#  {'entity': 'Facility',
#   'values': [{'value': "Jabba's palace"}, {'value': 'Imperial shuttle'}]},
#  {'entity': 'GeographicFeature', 'values': [{'value': 'Sarlacc pit'}]},
#  {'entity': 'Company',
#   'values': [{'value': 'Cloud City'}, {'value': 'Jawa traders'}]},
#  {'entity': 'Crime', 'values': [{'value': 'assault'}]}]

# %% [markdown]
# Update the workspace with these entities and verify that have been added correctly.

# %%
# Add these grouped entities to the Conversation workspace
conversation.update_workspace(workspace_id=wrk_id, entities=entities_grouped)

workspace_details = conversation.get_workspace(workspace_id=wrk_id, export=True)
print(json.dumps(workspace_details["entities"], indent=2))
# Out:
# [
#   {
#     "type": null,
#     "entity": "Location",
#     "source": null,
#     "values": [
#       {
#         "type": "synonyms",
#         "value": "Alderaan",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Sarlacc",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Dagobah",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       }
#     ],
#     "created": "2018-08-24T11:54:09.557Z",
#     "updated": "2018-08-24T11:54:09.557Z",
#     "open_list": null,
#     "description": null
#   },
#   {
#     "type": null,
#     "entity": "Crime",
#     "source": null,
#     "values": [
#       {
#         "type": "synonyms",
#         "value": "assault",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       }
#     ],
#     "created": "2018-08-24T11:54:09.557Z",
#     "updated": "2018-08-24T11:54:09.557Z",
#     "open_list": null,
#     "description": null
#   },
#   {
#     "type": null,
#     "entity": "Facility",
#     "source": null,
#     "values": [
#       {
#         "type": "synonyms",
#         "value": "Imperial shuttle",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Jabba's palace",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       }
#     ],
#     "created": "2018-08-24T11:54:09.557Z",
#     "updated": "2018-08-24T11:54:09.557Z",
#     "open_list": null,
#     "description": null
#   },
#   {
#     "type": null,
#     "entity": "Company",
#     "source": null,
#     "values": [
#       {
#         "type": "synonyms",
#         "value": "Jawa traders",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Cloud City",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       }
#     ],
#     "created": "2018-08-24T11:54:09.557Z",
#     "updated": "2018-08-24T11:54:09.557Z",
#     "open_list": null,
#     "description": null
#   },
#   {
#     "type": null,
#     "entity": "Organization",
#     "source": null,
#     "values": [
#       {
#         "type": "synonyms",
#         "value": "Rebel assault squadron",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Rebel Alliance",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Rebels",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Galactic Republic",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       }
#     ],
#     "created": "2018-08-24T11:54:09.557Z",
#     "updated": "2018-08-24T11:54:09.557Z",
#     "open_list": null,
#     "description": null
#   },
#   {
#     "type": null,
#     "entity": "GeographicFeature",
#     "source": null,
#     "values": [
#       {
#         "type": "synonyms",
#         "value": "Sarlacc pit",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       }
#     ],
#     "created": "2018-08-24T11:54:09.557Z",
#     "updated": "2018-08-24T11:54:09.557Z",
#     "open_list": null,
#     "description": null
#   },
#   {
#     "type": null,
#     "entity": "Person",
#     "source": null,
#     "values": [
#       {
#         "type": "synonyms",
#         "value": "Anakin Skywalker",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Emperor Palpatine",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Obi-Wan Kenobi",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Dagobah",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Princess Leia",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Wookiee",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Boba Fett",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Luke",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Beru Lars",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Palpatine",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Han",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Obi-Wan",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Anakin",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Vader",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Luke Skywalker",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Lando Calrissian",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Leia",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Darth Vader",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       },
#       {
#         "type": "synonyms",
#         "value": "Lando",
#         "created": "2018-08-24T11:54:09.557Z",
#         "updated": "2018-08-24T11:54:09.557Z",
#         "metadata": null,
#         "synonyms": []
#       }
#     ],
#     "created": "2018-08-24T11:54:09.557Z",
#     "updated": "2018-08-24T11:54:09.557Z",
#     "open_list": null,
#     "description": null
#   }
# ]

# %% [markdown]
# _**Note**: Ensure that at least 3 entity types, with at least 1 example entity each have been added._
#
# Here is what the list of entities should look like through the Conversation tool.
#
# <img src="images/conversation-entities.png" alt="Conversation service - Entities listed" width="800" />
#
# **Q**: Name 3 entity types that were added, with at least 1 example entity each (e.g. entity type: _City_, example: _Los Angeles_).
#
# **A**: @Facility:
# Imperial shuttle, Jabba's palace

# %% [markdown]
# ### Design dialog flow
#
# As a final step in creating the Conversation interface, let's design a typical dialog with a user. The most intuitive way to do this is to use the Dialog tab in the tool. Here, you can add _nodes_ that capture different stages in the dialog flow, and connect them in a meaningful way.
#
# Go ahead and add at least 3 dialog nodes. Specify the triggers in terms of the intents and entities that you'd like to match, and an optional intermediate response like "Let me find that out for you." The actual response will be fetched by querying the Discovery service.
#
# Here is what the dialog nodes should look like.
#
# <img src="images/conversation-dialog_nodes.png" alt="Conversation service - Dialog nodes" width="640" />
#
# **Q**: Specify 3 dialog nodes you added, along with the trigger (intent and/or entities) for each.
#
# **A**:
#     what: #what,
#     when: #when,
#     Where: #where

# %% [markdown]
# ### Test dialog
#
# Let's run through a test dialog to demonstrate how the system transitions to one of the nodes you defined above.

# %%
# Testing the dialog flow

# Start conversation with a blank message
results = conversation.message(workspace_id=wrk_id, message_input={})
context = results["context"]

# Then ask a sample question
question= "Who is Luke's father?"
results = conversation.message(workspace_id=wrk_id, message_input={
    "text": question,
    "context": context
})
print(json.dumps(results, indent=2))
# Out:
# {
#   "intents": [],
#   "entities": [],
#   "input": {},
#   "output": {
#     "text": [
#       "Hello. How can I help you?"
#     ],
#     "nodes_visited": [
#       "Welcome"
#     ],
#     "log_messages": []
#   },
#   "context": {
#     "conversation_id": "7a76c8fd-5f1c-47d7-9a68-7873e4f4ecc7",
#     "system": {
#       "dialog_stack": [
#         {
#           "dialog_node": "root"
#         }
#       ],
#       "dialog_turn_counter": 1,
#       "dialog_request_counter": 1,
#       "_node_output_map": {
#         "Welcome": {
#           "0": [
#             0
#           ]
#         }
#       },
#       "branch_exited": true,
#       "branch_exited_reason": "completed"
#     }
#   }
# }

# %% [markdown]
# ## 4. Query document collection to fetch answers
#
# The Discovery service includes a simple mechanism to make queries against your enriched collection of documents. But you have a lot of control over what fields are searched, how results are aggregated and values are returned.
#
# ### Process sample question
#
# Choose a sample nautal language question to ask, and run it through the Conversation service, just like you did above when testing dialog flow.

# %%
# TODO: Run a sample question through Conversation service
question = "who is anakin's dad?"

# Blank message
results = conversation.message(workspace_id=wrk_id, message_input={})
context = results["context"]

results = conversation.message(workspace_id=wrk_id, message_input={
    "text": question,
    "context": context
})

print(json.dumps(results, indent=2))
# Out:
# {
#   "intents": [],
#   "entities": [],
#   "input": {},
#   "output": {
#     "text": [
#       "Hello. How can I help you?"
#     ],
#     "nodes_visited": [
#       "Welcome"
#     ],
#     "log_messages": []
#   },
#   "context": {
#     "conversation_id": "a2f042e2-4f45-465d-bfe9-49909c07d30f",
#     "system": {
#       "dialog_stack": [
#         {
#           "dialog_node": "root"
#         }
#       ],
#       "dialog_turn_counter": 1,
#       "dialog_request_counter": 1,
#       "_node_output_map": {
#         "Welcome": {
#           "0": [
#             0
#           ]
#         }
#       },
#       "branch_exited": true,
#       "branch_exited_reason": "completed"
#     }
#   }
# }

# %% [markdown]
# Now extract the intent and entities identified in the question, and optionally what dialog node was triggered (in case you need it later to customize your response). Some sample code is provided below, but you may need to modify it.

# %%
# TODO: Identify the intent(s) the user expressed (typically a single one)
query_intents = [intent["intent"] for intent in results["intents"]]
print("Intent(s):", query_intents)

# TODO: Extract the entities found in the question text
query_entities = [entity["value"] for entity in results["entities"]]
print("Entities:", query_entities)

# TODO: (optional) Find out what dialog node was triggered
# Out:
# Intent(s): []
# Entities: []

# %% [markdown]
# ### Query the collection
#
# Design a query based on the information extracted above, and run it against the document collection. The sample query provided below simple looks for all the entities in the raw `text` field. Modify it to suit your needs.
#
# Take a look at the [API Reference](https://www.ibm.com/watson/developercloud/discovery/api/v1/?python#query-collection) to learn more about the query options available, and for more guidance see this [documentation page](https://www.ibm.com/watson/developercloud/doc/discovery/using.html).
#
# _**Note**: You may want to design different queries based on the intent / dialog node that was triggered._

# %%
# TODO: Query the Discovery service based on the intent and entities
query_results = discovery.query(environment_id=env_id, collection_id=col_id,
    query_options={
        "query": "text:{}".format(",".join("\"{}\"".format(e) for e in query_entities)),
        "return": "text"
    })
print(json.dumps(query_results, indent=2))
# Out:
# {
#   "matching_results": 84,
#   "session_token": "1_gEryBKuNHp667KW2_2L6AdPLPA",
#   "results": [
#     {
#       "id": "54c0a940-dbff-4a1f-b509-ea965a5ec2f5",
#       "score": 1,
#       "extracted_metadata": {
#         "sha1": "e08c8ac4caa59b97525ca22206bb5c130d49eb9f",
#         "filename": "Star Wars: Episode IV - A New Hope",
#         "file_type": "json"
#       },
#       "text": "The galaxy is in the midst of a civil war. Spies for the Rebel Alliance have stolen plans to the Galactic Empire's Death Star, a heavily armed space station capable of destroying an entire planet. Rebel leader Princess Leia has the plans, but her ship is captured by Imperial forces under the command of the evil Darth Vader. Before she is captured, Leia hides the plans in the memory of an astromech droid, R2-D2, along with a holographic recording. R2-D2 flees to the surface of the desert planet Tatooine with C-3PO, a protocol droid.",
#       "enriched_text": {
#         "entities": [
#           {
#             "count": 2,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Princess Leia",
#             "relevance": 0.842299,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": -0.371166,
#               "label": "negative"
#             },
#             "text": "Rebel Alliance",
#             "relevance": 0.725365,
#             "type": "Organization",
#             "disambiguation": {
#               "subtype": [],
#               "name": "Rebel Alliance",
#               "dbpedia_resource": "http://dbpedia.org/resource/Rebel_Alliance"
#             }
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Darth Vader",
#             "relevance": 0.663609,
#             "type": "Person"
#           }
#         ],
#         "sentiment": {
#           "document": {
#             "score": -0.454375,
#             "label": "negative"
#           }
#         },
#         "concepts": [
#           {
#             "text": "Star Wars Episode IV: A New Hope",
#             "relevance": 0.940792,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope"
#           },
#           {
#             "text": "Darth Vader",
#             "relevance": 0.683522,
#             "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#           },
#           {
#             "text": "Star Wars Episode VI: Return of the Jedi",
#             "relevance": 0.658553,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi"
#           },
#           {
#             "text": "Luke Skywalker",
#             "relevance": 0.628605,
#             "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#           },
#           {
#             "text": "Rebel Alliance",
#             "relevance": 0.567705,
#             "dbpedia_resource": "http://dbpedia.org/resource/Rebel_Alliance"
#           },
#           {
#             "text": "Star Wars",
#             "relevance": 0.558264,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars"
#           },
#           {
#             "text": "Star Wars Episode V: The Empire Strikes Back",
#             "relevance": 0.515003,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back"
#           },
#           {
#             "text": "Padm\u00e9 Amidala",
#             "relevance": 0.511318,
#             "dbpedia_resource": "http://dbpedia.org/resource/Padm\u00e9_Amidala"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.659455,
#             "label": "/society/unrest and war"
#           },
#           {
#             "score": 0.385555,
#             "label": "/law, govt and politics/armed forces/army"
#           },
#           {
#             "score": 0.373192,
#             "label": "/art and entertainment/movies and tv/movies"
#           }
#         ],
#         "relations": [
#           {
#             "type": "employedBy",
#             "sentence": "Spies for the Rebel Alliance have stolen plans to the Galactic Empire's Death Star, a heavily armed space station capable of destroying an entire planet.",
#             "score": 0.432905,
#             "arguments": [
#               {
#                 "text": "Spies",
#                 "location": [
#                   43,
#                   48
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Spies"
#                   }
#                 ]
#               },
#               {
#                 "text": "Rebel Alliance",
#                 "location": [
#                   57,
#                   71
#                 ],
#                 "entities": [
#                   {
#                     "type": "Organization",
#                     "text": "Rebel Alliance"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "affectedBy",
#             "sentence": "Rebel leader Princess Leia has the plans, but her ship is captured by Imperial forces under the command of the evil Darth Vader.",
#             "score": 0.5506,
#             "arguments": [
#               {
#                 "text": "Darth Vader",
#                 "location": [
#                   313,
#                   324
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Darth Vader"
#                   }
#                 ]
#               },
#               {
#                 "text": "captured",
#                 "location": [
#                   255,
#                   263
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventCustody",
#                     "text": "captured"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "employedBy",
#             "sentence": "Rebel leader Princess Leia has the plans, but her ship is captured by Imperial forces under the command of the evil Darth Vader.",
#             "score": 0.447149,
#             "arguments": [
#               {
#                 "text": "forces",
#                 "location": [
#                   276,
#                   282
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "forces"
#                   }
#                 ]
#               },
#               {
#                 "text": "Imperial",
#                 "location": [
#                   267,
#                   275
#                 ],
#                 "entities": [
#                   {
#                     "type": "Organization",
#                     "text": "Imperial",
#                     "disambiguation": {
#                       "subtype": [
#                         "Educational"
#                       ]
#                     }
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "locatedAt",
#             "sentence": "R2-D2 flees to the surface of the desert planet Tatooine with C-3PO, a protocol droid.",
#             "score": 0.608015,
#             "arguments": [
#               {
#                 "text": "desert",
#                 "location": [
#                   485,
#                   491
#                 ],
#                 "entities": [
#                   {
#                     "type": "GeographicFeature",
#                     "text": "desert"
#                   }
#                 ]
#               },
#               {
#                 "text": "planet",
#                 "location": [
#                   492,
#                   498
#                 ],
#                 "entities": [
#                   {
#                     "type": "GeopoliticalEntity",
#                     "text": "planet"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "residesIn",
#             "sentence": "R2-D2 flees to the surface of the desert planet Tatooine with C-3PO, a protocol droid.",
#             "score": 0.408702,
#             "arguments": [
#               {
#                 "text": "Tatooine",
#                 "location": [
#                   499,
#                   507
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Tatooine"
#                   }
#                 ]
#               },
#               {
#                 "text": "planet",
#                 "location": [
#                   492,
#                   498
#                 ],
#                 "entities": [
#                   {
#                     "type": "GeopoliticalEntity",
#                     "text": "planet"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "agentOf",
#             "sentence": "Spies for the Rebel Alliance have stolen plans to the Galactic Empire's Death Star, a heavily armed space station capable of destroying an entire planet.",
#             "score": 0.841626,
#             "arguments": [
#               {
#                 "text": "Spies",
#                 "location": [
#                   43,
#                   48
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Spies"
#                   }
#                 ]
#               },
#               {
#                 "text": "stolen",
#                 "location": [
#                   77,
#                   83
#                 ],
#                 "entities": [
#                   {
#                     "type": "Crime",
#                     "text": "stolen"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "locatedAt",
#             "sentence": "Spies for the Rebel Alliance have stolen plans to the Galactic Empire's Death Star, a heavily armed space station capable of destroying an entire planet.",
#             "score": 0.368034,
#             "arguments": [
#               {
#                 "text": "stolen",
#                 "location": [
#                   77,
#                   83
#                 ],
#                 "entities": [
#                   {
#                     "type": "Crime",
#                     "text": "stolen"
#                   }
#                 ]
#               },
#               {
#                 "text": "space station",
#                 "location": [
#                   143,
#                   156
#                 ],
#                 "entities": [
#                   {
#                     "type": "Facility",
#                     "text": "space station"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "awardedBy",
#             "sentence": "Spies for the Rebel Alliance have stolen plans to the Galactic Empire's Death Star, a heavily armed space station capable of destroying an entire planet.",
#             "score": 0.433922,
#             "arguments": [
#               {
#                 "text": "Death Star",
#                 "location": [
#                   115,
#                   125
#                 ],
#                 "entities": [
#                   {
#                     "type": "EntertainmentAward",
#                     "text": "Death Star"
#                   }
#                 ]
#               },
#               {
#                 "text": "Galactic Empire",
#                 "location": [
#                   97,
#                   112
#                 ],
#                 "entities": [
#                   {
#                     "type": "Organization",
#                     "text": "Galactic Empire"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "ownerOf",
#             "sentence": "Rebel leader Princess Leia has the plans, but her ship is captured by Imperial forces under the command of the evil Darth Vader.",
#             "score": 0.7592,
#             "arguments": [
#               {
#                 "text": "her",
#                 "location": [
#                   243,
#                   246
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Princess Leia"
#                   }
#                 ]
#               },
#               {
#                 "text": "ship",
#                 "location": [
#                   247,
#                   251
#                 ],
#                 "entities": [
#                   {
#                     "type": "Vehicle",
#                     "text": "ship"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "affectedBy",
#             "sentence": "Rebel leader Princess Leia has the plans, but her ship is captured by Imperial forces under the command of the evil Darth Vader.",
#             "score": 0.622576,
#             "arguments": [
#               {
#                 "text": "her",
#                 "location": [
#                   243,
#                   246
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Princess Leia"
#                   }
#                 ]
#               },
#               {
#                 "text": "captured",
#                 "location": [
#                   255,
#                   263
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventCustody",
#                     "text": "captured"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "affectedBy",
#             "sentence": "Before she is captured, Leia hides the plans in the memory of an astromech droid, R2-D2, along with a holographic recording.",
#             "score": 0.779858,
#             "arguments": [
#               {
#                 "text": "she",
#                 "location": [
#                   333,
#                   336
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Princess Leia"
#                   }
#                 ]
#               },
#               {
#                 "text": "captured",
#                 "location": [
#                   340,
#                   348
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventCustody",
#                     "text": "captured"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "locatedAt",
#             "sentence": "Rebel leader Princess Leia has the plans, but her ship is captured by Imperial forces under the command of the evil Darth Vader.",
#             "score": 0.487082,
#             "arguments": [
#               {
#                 "text": "forces",
#                 "location": [
#                   276,
#                   282
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "forces"
#                   }
#                 ]
#               },
#               {
#                 "text": "ship",
#                 "location": [
#                   247,
#                   251
#                 ],
#                 "entities": [
#                   {
#                     "type": "Vehicle",
#                     "text": "ship"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "agentOf",
#             "sentence": "Rebel leader Princess Leia has the plans, but her ship is captured by Imperial forces under the command of the evil Darth Vader.",
#             "score": 0.508423,
#             "arguments": [
#               {
#                 "text": "Imperial",
#                 "location": [
#                   267,
#                   275
#                 ],
#                 "entities": [
#                   {
#                     "type": "Organization",
#                     "text": "Imperial",
#                     "disambiguation": {
#                       "subtype": [
#                         "Educational"
#                       ]
#                     }
#                   }
#                 ]
#               },
#               {
#                 "text": "captured",
#                 "location": [
#                   255,
#                   263
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventCustody",
#                     "text": "captured"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "agentOf",
#             "sentence": "Rebel leader Princess Leia has the plans, but her ship is captured by Imperial forces under the command of the evil Darth Vader.",
#             "score": 0.630093,
#             "arguments": [
#               {
#                 "text": "forces",
#                 "location": [
#                   276,
#                   282
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "forces"
#                   }
#                 ]
#               },
#               {
#                 "text": "captured",
#                 "location": [
#                   255,
#                   263
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventCustody",
#                     "text": "captured"
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "keywords": [
#           {
#             "text": "leader Princess Leia",
#             "relevance": 0.928291
#           },
#           {
#             "text": "evil Darth Vader",
#             "relevance": 0.837133
#           },
#           {
#             "text": "heavily armed space",
#             "relevance": 0.81237
#           },
#           {
#             "text": "desert planet Tatooine",
#             "relevance": 0.742737
#           },
#           {
#             "text": "astromech droid",
#             "relevance": 0.698395
#           },
#           {
#             "text": "R2-D2 flees",
#             "relevance": 0.595591
#           },
#           {
#             "text": "protocol droid",
#             "relevance": 0.569795
#           },
#           {
#             "text": "Rebel Alliance",
#             "relevance": 0.532218
#           },
#           {
#             "text": "Galactic Empire",
#             "relevance": 0.440454
#           },
#           {
#             "text": "Imperial forces",
#             "relevance": 0.420099
#           },
#           {
#             "text": "civil war",
#             "relevance": 0.420079
#           },
#           {
#             "text": "holographic recording",
#             "relevance": 0.398598
#           },
#           {
#             "text": "entire planet",
#             "relevance": 0.389195
#           },
#           {
#             "text": "Death Star",
#             "relevance": 0.380692
#           }
#         ]
#       }
#     },
#     {
#       "id": "ea8d5605-7654-42f7-a6be-139615b5e224",
#       "score": 1,
#       "extracted_metadata": {
#         "sha1": "f583807ace9a1c8346ff1df285eb63bb651f0e46",
#         "filename": "Star Wars: Episode IV - A New Hope",
#         "file_type": "json"
#       },
#       "text": "Obi-Wan views Leia's complete message, in which she begs him to take the Death Star plans to her home planet of Alderaan and give them to her father for analysis. Obi-Wan invites Luke to accompany him to Alderaan and learn the ways of the Force. Luke declines, but changes his mind after discovering that Imperial stormtroopers searching for C-3PO and R2-D2 have destroyed his home and killed his aunt and uncle. Obi-Wan and Luke hire smuggler Han Solo and his Wookiee first mate Chewbacca to transport them to Alderaan on Han's ship, the Millennium Falcon.",
#       "enriched_text": {
#         "entities": [
#           {
#             "count": 3,
#             "sentiment": {
#               "score": 0.456493,
#               "label": "positive"
#             },
#             "text": "Alderaan",
#             "relevance": 0.809345,
#             "type": "Location",
#             "disambiguation": {
#               "subtype": [
#                 "City"
#               ]
#             }
#           },
#           {
#             "count": 4,
#             "sentiment": {
#               "score": 0.127858,
#               "label": "positive"
#             },
#             "text": "Luke",
#             "relevance": 0.572945,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Obi-Wan",
#             "relevance": 0.448136,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Wookiee",
#             "relevance": 0.243511,
#             "type": "Person"
#           }
#         ],
#         "sentiment": {
#           "document": {
#             "score": 0.4872,
#             "label": "positive"
#           }
#         },
#         "concepts": [
#           {
#             "text": "Star Wars Episode IV: A New Hope",
#             "relevance": 0.965661,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope"
#           },
#           {
#             "text": "Star Wars Episode III: Revenge of the Sith",
#             "relevance": 0.704354,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_III:_Revenge_of_the_Sith"
#           },
#           {
#             "text": "Darth Vader",
#             "relevance": 0.680625,
#             "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#           },
#           {
#             "text": "Obi-Wan Kenobi",
#             "relevance": 0.645474,
#             "dbpedia_resource": "http://dbpedia.org/resource/Obi-Wan_Kenobi"
#           },
#           {
#             "text": "Luke Skywalker",
#             "relevance": 0.641051,
#             "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#           },
#           {
#             "text": "Star Wars",
#             "relevance": 0.608656,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars"
#           },
#           {
#             "text": "Star Wars Episode VI: Return of the Jedi",
#             "relevance": 0.59977,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi"
#           },
#           {
#             "text": "R2-D2",
#             "relevance": 0.598672,
#             "dbpedia_resource": "http://dbpedia.org/resource/R2-D2"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.523003,
#             "label": "/law, govt and politics/armed forces/army"
#           },
#           {
#             "score": 0.242985,
#             "label": "/art and entertainment/movies and tv/movies"
#           },
#           {
#             "score": 0.121916,
#             "label": "/law, govt and politics/armed forces/air force"
#           }
#         ],
#         "relations": [
#           {
#             "type": "awardedTo",
#             "sentence": "Obi-Wan views Leia's complete message, in which she begs him to take the Death Star plans to her home planet of Alderaan and give them to her father for analysis.",
#             "score": 0.461637,
#             "arguments": [
#               {
#                 "text": "Death Star",
#                 "location": [
#                   73,
#                   83
#                 ],
#                 "entities": [
#                   {
#                     "type": "EntertainmentAward",
#                     "text": "Death Star"
#                   }
#                 ]
#               },
#               {
#                 "text": "she",
#                 "location": [
#                   48,
#                   51
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Leia"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "agentOf",
#             "sentence": "Obi-Wan invites Luke to accompany him to Alderaan and learn the ways of the Force.",
#             "score": 0.994476,
#             "arguments": [
#               {
#                 "text": "Obi-Wan",
#                 "location": [
#                   163,
#                   170
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Obi-Wan"
#                   }
#                 ]
#               },
#               {
#                 "text": "invites",
#                 "location": [
#                   171,
#                   178
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventCommunication",
#                     "text": "invites"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "affectedBy",
#             "sentence": "Obi-Wan invites Luke to accompany him to Alderaan and learn the ways of the Force.",
#             "score": 0.882088,
#             "arguments": [
#               {
#                 "text": "Luke",
#                 "location": [
#                   179,
#                   183
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Luke"
#                   }
#                 ]
#               },
#               {
#                 "text": "invites",
#                 "location": [
#                   171,
#                   178
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventCommunication",
#                     "text": "invites"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "basedIn",
#             "sentence": "Obi-Wan invites Luke to accompany him to Alderaan and learn the ways of the Force.",
#             "score": 0.555529,
#             "arguments": [
#               {
#                 "text": "Force",
#                 "location": [
#                   239,
#                   244
#                 ],
#                 "entities": [
#                   {
#                     "type": "Organization",
#                     "text": "Force"
#                   }
#                 ]
#               },
#               {
#                 "text": "Alderaan",
#                 "location": [
#                   204,
#                   212
#                 ],
#                 "entities": [
#                   {
#                     "type": "GeopoliticalEntity",
#                     "text": "Alderaan"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "ownerOf",
#             "sentence": "Luke declines, but changes his mind after discovering that Imperial stormtroopers searching for C-3PO and R2-D2 have destroyed his home and killed his aunt and uncle.",
#             "score": 0.580309,
#             "arguments": [
#               {
#                 "text": "his",
#                 "location": [
#                   373,
#                   376
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Luke"
#                   }
#                 ]
#               },
#               {
#                 "text": "home",
#                 "location": [
#                   377,
#                   381
#                 ],
#                 "entities": [
#                   {
#                     "type": "Facility",
#                     "text": "home"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "locatedAt",
#             "sentence": "Luke declines, but changes his mind after discovering that Imperial stormtroopers searching for C-3PO and R2-D2 have destroyed his home and killed his aunt and uncle.",
#             "score": 0.260102,
#             "arguments": [
#               {
#                 "text": "uncle",
#                 "location": [
#                   406,
#                   411
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Obi-Wan"
#                   }
#                 ]
#               },
#               {
#                 "text": "home",
#                 "location": [
#                   377,
#                   381
#                 ],
#                 "entities": [
#                   {
#                     "type": "Facility",
#                     "text": "home"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "relative",
#             "sentence": "Luke declines, but changes his mind after discovering that Imperial stormtroopers searching for C-3PO and R2-D2 have destroyed his home and killed his aunt and uncle.",
#             "score": 0.406856,
#             "arguments": [
#               {
#                 "text": "his",
#                 "location": [
#                   393,
#                   396
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Luke"
#                   }
#                 ]
#               },
#               {
#                 "text": "aunt",
#                 "location": [
#                   397,
#                   401
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "aunt"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "agentOf",
#             "sentence": "Obi-Wan and Luke hire smuggler Han Solo and his Wookiee first mate Chewbacca to transport them to Alderaan on Han's ship, the Millennium Falcon.",
#             "score": 0.814532,
#             "arguments": [
#               {
#                 "text": "Luke",
#                 "location": [
#                   425,
#                   429
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Luke"
#                   }
#                 ]
#               },
#               {
#                 "text": "hire",
#                 "location": [
#                   430,
#                   434
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventPersonnel",
#                     "text": "hire"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "partOfMany",
#             "sentence": "Obi-Wan and Luke hire smuggler Han Solo and his Wookiee first mate Chewbacca to transport them to Alderaan on Han's ship, the Millennium Falcon.",
#             "score": 0.938123,
#             "arguments": [
#               {
#                 "text": "Luke",
#                 "location": [
#                   425,
#                   429
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Luke"
#                   }
#                 ]
#               },
#               {
#                 "text": "them",
#                 "location": [
#                   503,
#                   507
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "them"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "affectedBy",
#             "sentence": "Obi-Wan and Luke hire smuggler Han Solo and his Wookiee first mate Chewbacca to transport them to Alderaan on Han's ship, the Millennium Falcon.",
#             "score": 0.691006,
#             "arguments": [
#               {
#                 "text": "smuggler",
#                 "location": [
#                   435,
#                   443
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Han Solo"
#                   }
#                 ]
#               },
#               {
#                 "text": "hire",
#                 "location": [
#                   430,
#                   434
#                 ],
#                 "entities": [
#                   {
#                     "type": "EventPersonnel",
#                     "text": "hire"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "partOfMany",
#             "sentence": "Obi-Wan and Luke hire smuggler Han Solo and his Wookiee first mate Chewbacca to transport them to Alderaan on Han's ship, the Millennium Falcon.",
#             "score": 0.701785,
#             "arguments": [
#               {
#                 "text": "smuggler",
#                 "location": [
#                   435,
#                   443
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Han Solo"
#                   }
#                 ]
#               },
#               {
#                 "text": "them",
#                 "location": [
#                   503,
#                   507
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "them"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "partOfMany",
#             "sentence": "Obi-Wan and Luke hire smuggler Han Solo and his Wookiee first mate Chewbacca to transport them to Alderaan on Han's ship, the Millennium Falcon.",
#             "score": 0.926946,
#             "arguments": [
#               {
#                 "text": "Han Solo",
#                 "location": [
#                   444,
#                   452
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Han Solo"
#                   }
#                 ]
#               },
#               {
#                 "text": "them",
#                 "location": [
#                   503,
#                   507
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "them"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "partOfMany",
#             "sentence": "Obi-Wan and Luke hire smuggler Han Solo and his Wookiee first mate Chewbacca to transport them to Alderaan on Han's ship, the Millennium Falcon.",
#             "score": 0.85473,
#             "arguments": [
#               {
#                 "text": "his",
#                 "location": [
#                   457,
#                   460
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Han Solo"
#                   }
#                 ]
#               },
#               {
#                 "text": "them",
#                 "location": [
#                   503,
#                   507
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "them"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "awardedTo",
#             "sentence": "Obi-Wan views Leia's complete message, in which she begs him to take the Death Star plans to her home planet of Alderaan and give them to her father for analysis.",
#             "score": 0.819002,
#             "arguments": [
#               {
#                 "text": "Death Star",
#                 "location": [
#                   73,
#                   83
#                 ],
#                 "entities": [
#                   {
#                     "type": "EntertainmentAward",
#                     "text": "Death Star"
#                   }
#                 ]
#               },
#               {
#                 "text": "him",
#                 "location": [
#                   57,
#                   60
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "him"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "partOfMany",
#             "sentence": "Obi-Wan and Luke hire smuggler Han Solo and his Wookiee first mate Chewbacca to transport them to Alderaan on Han's ship, the Millennium Falcon.",
#             "score": 0.592914,
#             "arguments": [
#               {
#                 "text": "mate",
#                 "location": [
#                   475,
#                   479
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Chewbacca"
#                   }
#                 ]
#               },
#               {
#                 "text": "them",
#                 "location": [
#                   503,
#                   507
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "them"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "partOfMany",
#             "sentence": "Obi-Wan and Luke hire smuggler Han Solo and his Wookiee first mate Chewbacca to transport them to Alderaan on Han's ship, the Millennium Falcon.",
#             "score": 0.797984,
#             "arguments": [
#               {
#                 "text": "Chewbacca",
#                 "location": [
#                   480,
#                   489
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Chewbacca"
#                   }
#                 ]
#               },
#               {
#                 "text": "them",
#                 "location": [
#                   503,
#                   507
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "them"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "residesIn",
#             "sentence": "Obi-Wan and Luke hire smuggler Han Solo and his Wookiee first mate Chewbacca to transport them to Alderaan on Han's ship, the Millennium Falcon.",
#             "score": 0.534389,
#             "arguments": [
#               {
#                 "text": "them",
#                 "location": [
#                   503,
#                   507
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "them"
#                   }
#                 ]
#               },
#               {
#                 "text": "Alderaan",
#                 "location": [
#                   511,
#                   519
#                 ],
#                 "entities": [
#                   {
#                     "type": "GeopoliticalEntity",
#                     "text": "Alderaan"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "locatedAt",
#             "sentence": "Obi-Wan and Luke hire smuggler Han Solo and his Wookiee first mate Chewbacca to transport them to Alderaan on Han's ship, the Millennium Falcon.",
#             "score": 0.714399,
#             "arguments": [
#               {
#                 "text": "them",
#                 "location": [
#                   503,
#                   507
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "them"
#                   }
#                 ]
#               },
#               {
#                 "text": "ship",
#                 "location": [
#                   529,
#                   533
#                 ],
#                 "entities": [
#                   {
#                     "type": "Vehicle",
#                     "text": "ship"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "awardedTo",
#             "sentence": "Obi-Wan views Leia's complete message, in which she begs him to take the Death Star plans to her home planet of Alderaan and give them to her father for analysis.",
#             "score": 0.452561,
#             "arguments": [
#               {
#                 "text": "Death Star",
#                 "location": [
#                   73,
#                   83
#                 ],
#                 "entities": [
#                   {
#                     "type": "EntertainmentAward",
#                     "text": "Death Star"
#                   }
#                 ]
#               },
#               {
#                 "text": "father",
#                 "location": [
#                   142,
#                   148
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Obi-Wan"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "residesIn",
#             "sentence": "Obi-Wan views Leia's complete message, in which she begs him to take the Death Star plans to her home planet of Alderaan and give them to her father for analysis.",
#             "score": 0.485975,
#             "arguments": [
#               {
#                 "text": "her",
#                 "location": [
#                   93,
#                   96
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Leia"
#                   }
#                 ]
#               },
#               {
#                 "text": "home",
#                 "location": [
#                   97,
#                   101
#                 ],
#                 "entities": [
#                   {
#                     "type": "Facility",
#                     "text": "home"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "residesIn",
#             "sentence": "Obi-Wan views Leia's complete message, in which she begs him to take the Death Star plans to her home planet of Alderaan and give them to her father for analysis.",
#             "score": 0.586493,
#             "arguments": [
#               {
#                 "text": "her",
#                 "location": [
#                   93,
#                   96
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Leia"
#                   }
#                 ]
#               },
#               {
#                 "text": "planet",
#                 "location": [
#                   102,
#                   108
#                 ],
#                 "entities": [
#                   {
#                     "type": "GeopoliticalEntity",
#                     "text": "planet"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "locatedAt",
#             "sentence": "Obi-Wan views Leia's complete message, in which she begs him to take the Death Star plans to her home planet of Alderaan and give them to her father for analysis.",
#             "score": 0.697454,
#             "arguments": [
#               {
#                 "text": "home",
#                 "location": [
#                   97,
#                   101
#                 ],
#                 "entities": [
#                   {
#                     "type": "Facility",
#                     "text": "home"
#                   }
#                 ]
#               },
#               {
#                 "text": "planet",
#                 "location": [
#                   102,
#                   108
#                 ],
#                 "entities": [
#                   {
#                     "type": "GeopoliticalEntity",
#                     "text": "planet"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "locatedAt",
#             "sentence": "Obi-Wan views Leia's complete message, in which she begs him to take the Death Star plans to her home planet of Alderaan and give them to her father for analysis.",
#             "score": 0.875843,
#             "arguments": [
#               {
#                 "text": "planet",
#                 "location": [
#                   102,
#                   108
#                 ],
#                 "entities": [
#                   {
#                     "type": "GeopoliticalEntity",
#                     "text": "planet"
#                   }
#                 ]
#               },
#               {
#                 "text": "Alderaan",
#                 "location": [
#                   112,
#                   120
#                 ],
#                 "entities": [
#                   {
#                     "type": "GeopoliticalEntity",
#                     "text": "Alderaan"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "partOfMany",
#             "sentence": "Obi-Wan views Leia's complete message, in which she begs him to take the Death Star plans to her home planet of Alderaan and give them to her father for analysis.",
#             "score": 0.342449,
#             "arguments": [
#               {
#                 "text": "father",
#                 "location": [
#                   142,
#                   148
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Obi-Wan"
#                   }
#                 ]
#               },
#               {
#                 "text": "them",
#                 "location": [
#                   130,
#                   134
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "them"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "parentOf",
#             "sentence": "Obi-Wan views Leia's complete message, in which she begs him to take the Death Star plans to her home planet of Alderaan and give them to her father for analysis.",
#             "score": 0.897131,
#             "arguments": [
#               {
#                 "text": "father",
#                 "location": [
#                   142,
#                   148
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Obi-Wan"
#                   }
#                 ]
#               },
#               {
#                 "text": "her",
#                 "location": [
#                   138,
#                   141
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Leia"
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "keywords": [
#           {
#             "text": "Obi-Wan invites Luke",
#             "relevance": 0.985722
#           },
#           {
#             "text": "Obi-Wan views Leia",
#             "relevance": 0.985631
#           },
#           {
#             "text": "smuggler Han Solo",
#             "relevance": 0.79731
#           },
#           {
#             "text": "Alderaan",
#             "relevance": 0.627846
#           },
#           {
#             "text": "Wookiee first mate",
#             "relevance": 0.587261
#           },
#           {
#             "text": "Imperial stormtroopers",
#             "relevance": 0.568236
#           },
#           {
#             "text": "Death Star",
#             "relevance": 0.538165
#           },
#           {
#             "text": "Millennium Falcon",
#             "relevance": 0.530428
#           },
#           {
#             "text": "home planet",
#             "relevance": 0.526118
#           },
#           {
#             "text": "C-3PO",
#             "relevance": 0.39422
# ...
#           },
#           {
#             "type": "partOfMany",
#             "sentence": "During his training on Dagobah, Luke sees a premonition of Han and Leia in pain in a city in the clouds and, against Yoda's wishes, leaves to save them.",
#             "score": 0.840254,
#             "arguments": [
#               {
#                 "text": "Yoda",
#                 "location": [
#                   609,
#                   613
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Yoda"
#                   }
#                 ]
#               },
#               {
#                 "text": "them",
#                 "location": [
#                   639,
#                   643
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "they"
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "keywords": [
#           {
#             "text": "Boba Fett",
#             "relevance": 0.974245
#           },
#           {
#             "text": "giant planet Bespin",
#             "relevance": 0.971794
#           },
#           {
#             "text": "Cloud City",
#             "relevance": 0.927583
#           },
#           {
#             "text": "Lando Calrissian",
#             "relevance": 0.792349
#           },
#           {
#             "text": "Darth Vader",
#             "relevance": 0.733425
#           },
#           {
#             "text": "floating colony",
#             "relevance": 0.710315
#           },
#           {
#             "text": "Han",
#             "relevance": 0.679543
#           },
#           {
#             "text": "Millennium Falcon",
#             "relevance": 0.671258
#           },
#           {
#             "text": "Luke",
#             "relevance": 0.526571
#           },
#           {
#             "text": "Dagobah",
#             "relevance": 0.494289
#           },
#           {
#             "text": "Empire",
#             "relevance": 0.491647
#           },
#           {
#             "text": "premonition",
#             "relevance": 0.484378
#           },
#           {
#             "text": "group",
#             "relevance": 0.483221
#           },
#           {
#             "text": "Leia",
#             "relevance": 0.473809
#           },
#           {
#             "text": "skies",
#             "relevance": 0.470685
#           },
#           {
#             "text": "Yoda",
#             "relevance": 0.4703
#           },
#           {
#             "text": "bait",
#             "relevance": 0.46182
#           },
#           {
#             "text": "clouds",
#             "relevance": 0.460368
#           },
#           {
#             "text": "trap",
#             "relevance": 0.45835
#           },
#           {
#             "text": "wishes",
#             "relevance": 0.457006
#           },
#           {
#             "text": "Emperor",
#             "relevance": 0.450858
#           },
#           {
#             "text": "course",
#             "relevance": 0.449356
#           },
#           {
#             "text": "gas",
#             "relevance": 0.448848
#           }
#         ]
#       }
#     },
#     {
#       "id": "f165d1f6-76c9-4009-9cb9-3c51f3a118f1",
#       "score": 1,
#       "extracted_metadata": {
#         "sha1": "6ff3f2e2a78225d8ff8c9ec5f726f5e64bfb9088",
#         "filename": "Star Wars: Episode V - The Empire Strikes Back",
#         "file_type": "json"
#       },
#       "text": "On patrol, Han and Chewbacca discover the meteor Luke had planned to investigate is actually a probe droid, which alerts the Empire to the Rebels\u2019 location. The Empire launches a large-scale attack, using AT-AT Walkers to capture the base. Despite heavy resistance, the Walkers destroy the base's shield generator and force the Rebels to retreat. Han and Leia escape on the Millennium Falcon with C-3PO and Chewbacca, but their hyperdrive malfunctions. They hide in an asteroid field, where Han and Leia grow closer, and eventually, kiss. Vader summons bounty hunters, including the notorious Boba Fett, to assist in finding the Falcon. Luke, meanwhile, escapes with R2-D2 in his X-wing fighter and crash-lands on the swamp planet Dagobah. He meets a diminutive creature who is revealed to be Yoda; after conferring with Obi-Wan's spirit, Yoda reluctantly accepts Luke as his student. Yoda trains Luke as a Jedi and raises his sunken ship from the swamp with the power of the Force.",
#       "enriched_text": {
#         "entities": [
#           {
#             "count": 3,
#             "sentiment": {
#               "score": -0.215266,
#               "label": "negative"
#             },
#             "text": "Han",
#             "relevance": 0.818713,
#             "type": "Person"
#           },
#           {
#             "count": 4,
#             "sentiment": {
#               "score": 0.525335,
#               "label": "positive"
#             },
#             "text": "Luke",
#             "relevance": 0.809336,
#             "type": "Person"
#           },
#           {
#             "count": 3,
#             "sentiment": {
#               "score": -0.284974,
#               "label": "negative"
#             },
#             "text": "Rebels",
#             "relevance": 0.733416,
#             "type": "Organization",
#             "disambiguation": {
#               "subtype": [],
#               "name": "Rebel Alliance",
#               "dbpedia_resource": "http://dbpedia.org/resource/Rebel_Alliance"
#             }
#           },
#           {
#             "count": 2,
#             "sentiment": {
#               "score": -0.215266,
#               "label": "negative"
#             },
#             "text": "Leia",
#             "relevance": 0.521629,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0.393721,
#               "label": "positive"
#             },
#             "text": "Boba Fett",
#             "relevance": 0.390569,
#             "type": "Person"
#           },
#           {
#             "count": 1,
#             "sentiment": {
#               "score": 0,
#               "label": "neutral"
#             },
#             "text": "Obi-Wan",
#             "relevance": 0.323172,
#             "type": "Person"
#           }
#         ],
#         "sentiment": {
#           "document": {
#             "score": -0.0793576,
#             "label": "negative"
#           }
#         },
#         "concepts": [
#           {
#             "text": "Star Wars Episode V: The Empire Strikes Back",
#             "relevance": 0.98679,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_V:_The_Empire_Strikes_Back"
#           },
#           {
#             "text": "Obi-Wan Kenobi",
#             "relevance": 0.982873,
#             "dbpedia_resource": "http://dbpedia.org/resource/Obi-Wan_Kenobi"
#           },
#           {
#             "text": "Star Wars Episode VI: Return of the Jedi",
#             "relevance": 0.958163,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_VI:_Return_of_the_Jedi"
#           },
#           {
#             "text": "Luke Skywalker",
#             "relevance": 0.950101,
#             "dbpedia_resource": "http://dbpedia.org/resource/Luke_Skywalker"
#           },
#           {
#             "text": "Star Wars Episode IV: A New Hope",
#             "relevance": 0.889181,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_IV:_A_New_Hope"
#           },
#           {
#             "text": "Star Wars Episode III: Revenge of the Sith",
#             "relevance": 0.84769,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars_Episode_III:_Revenge_of_the_Sith"
#           },
#           {
#             "text": "Darth Vader",
#             "relevance": 0.806361,
#             "dbpedia_resource": "http://dbpedia.org/resource/Darth_Vader"
#           },
#           {
#             "text": "Star Wars",
#             "relevance": 0.774658,
#             "dbpedia_resource": "http://dbpedia.org/resource/Star_Wars"
#           }
#         ],
#         "categories": [
#           {
#             "score": 0.472034,
#             "label": "/art and entertainment/movies and tv/movies"
#           },
#           {
#             "score": 0.262301,
#             "label": "/family and parenting/children"
#           },
#           {
#             "score": 0.251831,
#             "label": "/art and entertainment/books and literature/fan fiction"
#           }
#         ],
#         "relations": [
#           {
#             "type": "memberOf",
#             "sentence": "Despite heavy resistance, the Walkers destroy the base's shield generator and force the Rebels to retreat.",
#             "score": 0.220397,
#             "arguments": [
#               {
#                 "text": "Rebels",
#                 "location": [
#                   328,
#                   334
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Rebels"
#                   }
#                 ]
#               },
#               {
#                 "text": "Walkers",
#                 "location": [
#                   270,
#                   277
#                 ],
#                 "entities": [
#                   {
#                     "type": "Organization",
#                     "text": "AT-AT Walkers"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "partOfMany",
#             "sentence": "Han and Leia escape on the Millennium Falcon with C-3PO and Chewbacca, but their hyperdrive malfunctions.",
#             "score": 0.722787,
#             "arguments": [
#               {
#                 "text": "Leia",
#                 "location": [
#                   355,
#                   359
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Leia"
#                   }
#                 ]
#               },
#               {
#                 "text": "their",
#                 "location": [
#                   422,
#                   427
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "their"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "partOfMany",
#             "sentence": "Han and Leia escape on the Millennium Falcon with C-3PO and Chewbacca, but their hyperdrive malfunctions.",
#             "score": 0.891798,
#             "arguments": [
#               {
#                 "text": "Chewbacca",
#                 "location": [
#                   407,
#                   416
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Chewbacca"
#                   }
#                 ]
#               },
#               {
#                 "text": "their",
#                 "location": [
#                   422,
#                   427
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "their"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "partOfMany",
#             "sentence": "Vader summons bounty hunters, including the notorious Boba Fett, to assist in finding the Falcon.",
#             "score": 0.735203,
#             "arguments": [
#               {
#                 "text": "Boba Fett",
#                 "location": [
#                   593,
#                   602
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Boba Fett"
#                   }
#                 ]
#               },
#               {
#                 "text": "hunters",
#                 "location": [
#                   560,
#                   567
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "hunters"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "parentOf",
#             "sentence": "He meets a diminutive creature who is revealed to be Yoda; after conferring with Obi-Wan's spirit, Yoda reluctantly accepts Luke as his student.",
#             "score": 0.306441,
#             "arguments": [
#               {
#                 "text": "his",
#                 "location": [
#                   872,
#                   875
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Leia"
#                   }
#                 ]
#               },
#               {
#                 "text": "student",
#                 "location": [
#                   876,
#                   883
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Luke"
#                   }
#                 ]
#               }
#             ]
#           },
#           {
#             "type": "locatedAt",
#             "sentence": "Yoda trains Luke as a Jedi and raises his sunken ship from the swamp with the power of the Force.",
#             "score": 0.377055,
#             "arguments": [
#               {
#                 "text": "Yoda",
#                 "location": [
#                   885,
#                   889
#                 ],
#                 "entities": [
#                   {
#                     "type": "Person",
#                     "text": "Yoda"
#                   }
#                 ]
#               },
#               {
#                 "text": "trains",
#                 "location": [
#                   890,
#                   896
#                 ],
#                 "entities": [
#                   {
#                     "type": "Vehicle",
#                     "text": "trains"
#                   }
#                 ]
#               }
#             ]
#           }
#         ],
#         "keywords": [
#           {
#             "text": "Yoda trains Luke",
#             "relevance": 0.925008
#           },
#           {
#             "text": "swamp planet Dagobah",
#             "relevance": 0.755071
#           },
#           {
#             "text": "notorious Boba Fett",
#             "relevance": 0.753505
#           },
#           {
#             "text": "Vader summons bounty",
#             "relevance": 0.748439
#           },
#           {
#             "text": "meteor Luke",
#             "relevance": 0.633223
#           },
#           {
#             "text": "Leia escape",
#             "relevance": 0.524523
#           },
#           {
#             "text": "probe droid",
#             "relevance": 0.52301
#           },
#           {
#             "text": "AT-AT Walkers",
#             "relevance": 0.489112
#           },
#           {
#             "text": "hyperdrive malfunctions",
#             "relevance": 0.463966
#           },
#           {
#             "text": "Millennium Falcon",
#             "relevance": 0.460456
#           },
#           {
#             "text": "diminutive creature",
#             "relevance": 0.457027
#           },
#           {
#             "text": "large-scale attack",
#             "relevance": 0.448721
#           },
#           {
#             "text": "shield generator",
#             "relevance": 0.43799
#           },
#           {
#             "text": "heavy resistance",
#             "relevance": 0.432188
#           },
#           {
#             "text": "asteroid field",
#             "relevance": 0.428843
#           },
#           {
#             "text": "sunken ship",
#             "relevance": 0.428402
#           },
#           {
#             "text": "Han",
#             "relevance": 0.420286
#           },
#           {
#             "text": "Chewbacca",
#             "relevance": 0.347802
#           },
#           {
#             "text": "Rebels",
#             "relevance": 0.290302
#           },
#           {
#             "text": "C-3PO",
#             "relevance": 0.218126
#           },
#           {
#             "text": "Empire",
#             "relevance": 0.206999
#           },
#           {
#             "text": "base",
#             "relevance": 0.201784
#           }
#         ]
#       }
#     }
#   ]
# }

# %% [markdown]
# ### Process returned results
#
# If you properly structure the query, Watson is able to do a pretty good job of finding the relevant information. But the result returned is a JSON object. Now your task is to convert that result into an appropriate response that best addresses the original natural language question that was asked.
#
# E.g. if the question was "Who saved Han Solo from Jabba the Hutt?" the answer should ideally just be "The Rebels" and not the entire paragraph describing Han Solo's rescue. But that can be a backup response if you cannot be more specific.
#
# _**Note**: You may have to go back to the previous step and modify the query, especially what you want the Discovery service to return, and this may depend on the intent / dialog node triggered. E.g. study the different parts of a "relation" structure to see how you might construct queries to match them._

# %%
# TODO: Process returned results and compose an appropriate response

# %% [markdown]
# ## 5. Reflections
#
# **Q**: Now that you have gone through this exercise of designing a system that uses two IBM Watson services, what did you learn? What were some of the strengths and weaknesses of this approach?
#
# **A**:
#
#
# ## (Optional) Extensions
#
# We have provided a set of sample data files containing Star Wars plot summaries. But as mentioned before, you are free to use your own dataset. In fact, a larger dataset maybe more suitable for use with IBM Watson's NLP services. If you used your own dataset, answer the following questions.
#
# **Q**: What dataset did you use, and in what ways is it different from the sample files provided?
#
# **A**:
#
#
# **Q**: Either include your dataset in the .zip file or repository you submit, or provide clear instructions on how to obtain the dataset, so that your reviewer can run your notebook or inspect the data to verify your results.
#
# **A**:
#
#
# _You can also design a web-based application that utilizes these services and deploy that on Bluemix! If you do, please share with your instructors and peers._
